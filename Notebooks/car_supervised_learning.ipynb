# %% [markdown]
# # Supervised Learning Model
# This notebook contains supervised learning model using Balanced Random Forest Classifier to see what features from the used car dataset influence the target of price.

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func, inspect
from config import password

# %% [markdown]
# The first model used is BRFC used on all features besides identifier and geographical columns. The BRFC is then used on a sample of 5000. It is also worth mentioning that the price column is converted into 7 seperate bins to reduce the amount of unique prices.

# %%
file_path = 'Used_Cars.csv'
df = pd.read_csv(file_path)
df.head()
# Out:
# C:\Users\junio\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#    Unnamed: 0             id                vin    price     miles  \
# 0           0  38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0
# 1           1  97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0
# 2           2  be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0
# 3           3  84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0
# 4           6  43847b9a-6fed  1B7HC16Y8YS543285   3995.0  137537.0
#
#      stock_no    year        make          model      trim  ... drivetrain  \
# 0  W1T503168C  2015.0   Chevrolet  Express Cargo  Work Van  ...        RWD
# 1      P33243  2018.0         BMW             i3         s  ...        RWD
# 2     WM2091A  2018.0  Mitsubishi      Mirage G4        SE  ...        FWD
# 3    9U2Y425A  2019.0   Chevrolet       Colorado       ZR2  ...        4WD
# 4     BP8246A  2000.0       Dodge     Ram Pickup        ST  ...        RWD
#
#   transmission                    fuel_type engine_size engine_block  \
# 0    Automatic               E85 / Unleaded         4.8            V
# 1    Automatic  Electric / Premium Unleaded         0.6            I
# 2    Automatic                     Unleaded         1.2            I
# 3    Automatic                       Diesel         2.8            I
# 4       Manual                     Unleaded         5.2            V
#
#                     seller_name                        street           city  \
# 0          nissan ellicott city  8569 Baltimore National Pike  Ellicott City
# 1  hendrick honda pompano beach        5381 N Federal Highway  Pompano Beach
# 2            russ darrow toyota      2700 West Washington St.      West Bend
# 3                     young kia         308 North Main Street         Layton
# 4            baumann auto group             2379 W. State St.        Fremont
#
#   state    zip
# 0    MD  21043
# 1    FL  33064
# 2    WI  53095
# 3    UT  84041
# 4    OH  43420
#
# [5 rows x 22 columns]

# %%
clean_df = df.drop(columns=['Unnamed: 0', 'id', 'vin', 'seller_name', 'street', 'stock_no', 'city', 'state', 'zip',])
clean_df.drop(clean_df.loc[clean_df['miles'] == 0].index, inplace=True)
clean_df = clean_df.sample(n=5000)
clean_df.head()
# Out:
#            price     miles    year     make        model    trim  body_type  \
# 3157429  25995.0   40067.0  2019.0  Lincoln          MKC  Select        SUV
# 5343413  21995.0   17799.0  2015.0    Honda       Accord   Sport      Sedan
# 3964742  24100.0    7790.0  2020.0   Nissan        Rogue       S  Crossover
# 718024    7745.0  125523.0  2009.0    Honda       Accord      EX      Sedan
# 2928559  22991.0   26343.0  2011.0      GMC  Sierra 1500     SLE     Pickup
#
#         vehicle_type drivetrain transmission       fuel_type  engine_size  \
# 3157429        Truck        FWD    Automatic        Unleaded          2.0
# 5343413          Car        FWD    Automatic        Unleaded          2.4
# 3964742        Truck        FWD    Automatic        Unleaded          2.5
# 718024           Car        FWD    Automatic        Unleaded          2.4
# 2928559        Truck        RWD    Automatic  E85 / Unleaded          5.3
#
#         engine_block
# 3157429            I
# 5343413            I
# 3964742            I
# 718024             I
# 2928559            V

# %%
clean_df.describe()
# Out:
#                price          miles         year  engine_size
# count    5000.000000    5000.000000  5000.000000  5000.000000
# mean    28057.256000   52238.198200  2016.747400     3.110980
# std     16621.071408   42287.662736     3.242298     1.340305
# min      2790.000000       1.000000  1997.000000     0.600000
# 25%     17500.000000   22747.250000  2016.000000     2.000000
# 50%     24708.500000   39105.500000  2018.000000     2.500000
# 75%     35291.500000   72429.750000  2019.000000     3.600000
# max    333383.000000  359920.000000  2021.000000     7.300000

# %%
bins = [0, 5000, 10000, 15000, 25000, 50000, 100000, 400000]
labels = ['0-4,999', '5,000-9,999', '10,000-14999', '15,000-24,999', '25,000-49,999', '50,000-99,999', '100,000-400,000']

# %%
clean_df['price'] = pd.cut(clean_df['price'], bins, labels=labels )

# %%
clean_df
# Out:
#                  price     miles    year     make        model     trim  \
# 3157429  25,000-49,999   40067.0  2019.0  Lincoln          MKC   Select
# 5343413  15,000-24,999   17799.0  2015.0    Honda       Accord    Sport
# 3964742  15,000-24,999    7790.0  2020.0   Nissan        Rogue        S
# 718024     5,000-9,999  125523.0  2009.0    Honda       Accord       EX
# 2928559  15,000-24,999   26343.0  2011.0      GMC  Sierra 1500      SLE
# ...                ...       ...     ...      ...          ...      ...
# 3930598  15,000-24,999   23489.0  2018.0   Toyota         RAV4      XLE
# 5775382  25,000-49,999   59844.0  2016.0     Ford     Explorer      XLT
# 3923734  15,000-24,999  135989.0  2015.0   Toyota         RAV4  Limited
# 1920072  25,000-49,999   51021.0  2015.0      BMW     5 Series     535i
# 5256368  15,000-24,999   33107.0  2016.0   Toyota      Corolla       LE
#
#          body_type vehicle_type drivetrain transmission         fuel_type  \
# 3157429        SUV        Truck        FWD    Automatic          Unleaded
# 5343413      Sedan          Car        FWD    Automatic          Unleaded
# 3964742  Crossover        Truck        FWD    Automatic          Unleaded
# 718024       Sedan          Car        FWD    Automatic          Unleaded
# 2928559     Pickup        Truck        RWD    Automatic    E85 / Unleaded
# ...            ...          ...        ...          ...               ...
# 3930598        SUV        Truck        4WD    Automatic          Unleaded
# 5775382        SUV        Truck        FWD    Automatic    E85 / Unleaded
# 3923734        SUV        Truck        4WD    Automatic          Unleaded
# 1920072      Sedan          Car        4WD    Automatic  Premium Unleaded
# 5256368      Sedan          Car        FWD    Automatic          Unleaded
#
#          engine_size engine_block
# 3157429          2.0            I
# 5343413          2.4            I
# 3964742          2.5            I
# 718024           2.4            I
# 2928559          5.3            V
# ...              ...          ...
# 3930598          2.5            I
# 5775382          3.5            V
# 3923734          2.5            I
# 1920072          3.0            I
# 5256368          1.8            I
#
# [5000 rows x 13 columns]

# %%
clean_df.nunique()
# Out:
# price              7
# miles           4866
# year              25
# make              43
# model            442
# trim             476
# body_type         16
# vehicle_type       2
# drivetrain         3
# transmission       2
# fuel_type         13
# engine_size       51
# engine_block       3
# dtype: int64

# %%
clean_df['price'].describe()
# Out:
# count              5000
# unique                7
# top       25,000-49,999
# freq               2032
# Name: price, dtype: object

# %%
clean_df = clean_df.dropna()

# %%
drop_columns = ['price_0-4,999', 'price_5,000-9,999', 'price_10,000-14999', 'price_15,000-24,999', 'price_25,000-49,999', 'price_50,000-99,999', 'price_100,000-400,000']

# %%
X = pd.get_dummies(clean_df)
X = X.drop(columns=drop_columns)
y = clean_df['price']

# %%
X
# Out:
#             miles    year  engine_size  make_Acura  make_Alfa Romeo  \
# 3157429   40067.0  2019.0          2.0           0                0
# 5343413   17799.0  2015.0          2.4           0                0
# 3964742    7790.0  2020.0          2.5           0                0
# 718024   125523.0  2009.0          2.4           0                0
# 2928559   26343.0  2011.0          5.3           0                0
# ...           ...     ...          ...         ...              ...
# 3930598   23489.0  2018.0          2.5           0                0
# 5775382   59844.0  2016.0          3.5           0                0
# 3923734  135989.0  2015.0          2.5           0                0
# 1920072   51021.0  2015.0          3.0           0                0
# 5256368   33107.0  2016.0          1.8           0                0
#
#          make_Audi  make_BMW  make_Bentley  make_Buick  make_Cadillac  ...  \
# 3157429          0         0             0           0              0  ...
# 5343413          0         0             0           0              0  ...
# 3964742          0         0             0           0              0  ...
# 718024           0         0             0           0              0  ...
# 2928559          0         0             0           0              0  ...
# ...            ...       ...           ...         ...            ...  ...
# 3930598          0         0             0           0              0  ...
# 5775382          0         0             0           0              0  ...
# 3923734          0         0             0           0              0  ...
# 1920072          0         1             0           0              0  ...
# 5256368          0         0             0           0              0  ...
#
#          fuel_type_Electric / Premium Unleaded  fuel_type_Electric / Unleaded  \
# 3157429                                      0                              0
# 5343413                                      0                              0
# 3964742                                      0                              0
# 718024                                       0                              0
# 2928559                                      0                              0
# ...                                        ...                            ...
# 3930598                                      0                              0
# 5775382                                      0                              0
# 3923734                                      0                              0
# 1920072                                      0                              0
# 5256368                                      0                              0
#
#          fuel_type_Premium Unleaded  fuel_type_Premium Unleaded / Unleaded  \
# 3157429                           0                                      0
# 5343413                           0                                      0
# 3964742                           0                                      0
# 718024                            0                                      0
# 2928559                           0                                      0
# ...                             ...                                    ...
# 3930598                           0                                      0
# 5775382                           0                                      0
# 3923734                           0                                      0
# 1920072                           1                                      0
# 5256368                           0                                      0
#
#          fuel_type_Premium Unleaded; Unleaded  fuel_type_Unleaded  \
# 3157429                                     0                   1
# 5343413                                     0                   1
# 3964742                                     0                   1
# 718024                                      0                   1
# 2928559                                     0                   0
# ...                                       ...                 ...
# 3930598                                     0                   1
# 5775382                                     0                   0
# 3923734                                     0                   1
# 1920072                                     0                   0
# 5256368                                     0                   1
#
#          fuel_type_Unleaded / Unleaded  engine_block_H  engine_block_I  \
# 3157429                              0               0               1
# 5343413                              0               0               1
# 3964742                              0               0               1
# 718024                               0               0               1
# 2928559                              0               0               0
# ...                                ...             ...             ...
# 3930598                              0               0               1
# 5775382                              0               0               0
# 3923734                              0               0               1
# 1920072                              0               0               1
# 5256368                              0               0               1
#
#          engine_block_V
# 3157429               0
# 5343413               0
# 3964742               0
# 718024                0
# 2928559               1
# ...                 ...
# 3930598               0
# 5775382               1
# 3923734               0
# 1920072               0
# 5256368               0
#
# [5000 rows x 1003 columns]

# %%
X.describe()
# Out:
#                miles         year  engine_size  make_Acura  make_Alfa Romeo  \
# count    5000.000000  5000.000000  5000.000000  5000.00000      5000.000000
# mean    52238.198200  2016.747400     3.110980     0.01520         0.001600
# std     42287.662736     3.242298     1.340305     0.12236         0.039972
# min         1.000000  1997.000000     0.600000     0.00000         0.000000
# 25%     22747.250000  2016.000000     2.000000     0.00000         0.000000
# 50%     39105.500000  2018.000000     2.500000     0.00000         0.000000
# 75%     72429.750000  2019.000000     3.600000     0.00000         0.000000
# max    359920.000000  2021.000000     7.300000     1.00000         1.000000
#
#          make_Audi     make_BMW  make_Bentley  make_Buick  make_Cadillac  ...  \
# count  5000.000000  5000.000000   5000.000000  5000.00000     5000.00000  ...
# mean      0.018000     0.044000      0.000200     0.01520        0.01520  ...
# std       0.132964     0.205116      0.014142     0.12236        0.12236  ...
# min       0.000000     0.000000      0.000000     0.00000        0.00000  ...
# 25%       0.000000     0.000000      0.000000     0.00000        0.00000  ...
# 50%       0.000000     0.000000      0.000000     0.00000        0.00000  ...
# 75%       0.000000     0.000000      0.000000     0.00000        0.00000  ...
# max       1.000000     1.000000      1.000000     1.00000        1.00000  ...
#
#        fuel_type_Electric / Premium Unleaded  fuel_type_Electric / Unleaded  \
# count                            5000.000000                    5000.000000
# mean                                0.004800                       0.020200
# std                                 0.069122                       0.140698
# min                                 0.000000                       0.000000
# 25%                                 0.000000                       0.000000
# 50%                                 0.000000                       0.000000
# 75%                                 0.000000                       0.000000
# max                                 1.000000                       1.000000
#
#        fuel_type_Premium Unleaded  fuel_type_Premium Unleaded / Unleaded  \
# count                 5000.000000                             5000.00000
# mean                     0.220000                                0.00060
# std                      0.414288                                0.02449
# min                      0.000000                                0.00000
# 25%                      0.000000                                0.00000
# 50%                      0.000000                                0.00000
# 75%                      0.000000                                0.00000
# max                      1.000000                                1.00000
#
#        fuel_type_Premium Unleaded; Unleaded  fuel_type_Unleaded  \
# count                            5000.00000         5000.000000
# mean                                0.00100            0.654600
# std                                 0.03161            0.475546
# min                                 0.00000            0.000000
# 25%                                 0.00000            0.000000
# 50%                                 0.00000            1.000000
# 75%                                 0.00000            1.000000
# max                                 1.00000            1.000000
#
#        fuel_type_Unleaded / Unleaded  engine_block_H  engine_block_I  \
# count                    5000.000000     5000.000000     5000.000000
# mean                        0.000800        0.028600        0.505800
# std                         0.028276        0.166696        0.500016
# min                         0.000000        0.000000        0.000000
# 25%                         0.000000        0.000000        0.000000
# 50%                         0.000000        0.000000        1.000000
# 75%                         0.000000        0.000000        1.000000
# max                         1.000000        1.000000        1.000000
#
#        engine_block_V
# count     5000.000000
# mean         0.465600
# std          0.498865
# min          0.000000
# 25%          0.000000
# 50%          0.000000
# 75%          1.000000
# max          1.000000
#
# [8 rows x 1003 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (3750, 1003)

# %%
from imblearn.ensemble import BalancedRandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
clf = BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_train, y_train)

# %%
# Display the confusion matrix
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[  5,   0,   0,   0,   0,   5,   0],
#        [ 13,  62,   5,  22,   5,  17,   3],
#        [  0,   0,   3,   0,   0,   0,   0],
#        [ 10,  64,  14, 260,  70,   8,  13],
#        [  0,   1,  44, 104, 249,   0,  99],
#        [ 24,  18,   1,   1,   1,  31,   3],
#        [  0,   0,  31,   2,  10,   0,  52]], dtype=int64)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5744605174605378

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                        pre       rec       spe        f1       geo       iba       sup
#
#         0-4,999       0.10      0.50      0.96      0.16      0.69      0.46        10
#    10,000-14999       0.43      0.49      0.93      0.46      0.67      0.43       127
# 100,000-400,000       0.03      1.00      0.92      0.06      0.96      0.93         3
#   15,000-24,999       0.67      0.59      0.84      0.63      0.71      0.49       439
#   25,000-49,999       0.74      0.50      0.89      0.60      0.67      0.43       497
#     5,000-9,999       0.51      0.39      0.97      0.44      0.62      0.36        79
#   50,000-99,999       0.31      0.55      0.90      0.39      0.70      0.47        95
#
#     avg / total       0.63      0.53      0.88      0.56      0.68      0.45      1250

# %%
# List the features sorted in descending order by feature importance
sorted(zip(clf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.09394590297994633, 'year'),
#  (0.08896593232456786, 'miles'),
#  (0.06463679499746655, 'engine_size'),
#  (0.0245411833659355, 'fuel_type_Unleaded'),
#  (0.023154176373687833, 'fuel_type_Premium Unleaded'),
#  (0.02044200724534808, 'drivetrain_FWD'),
#  (0.019861271704586334, 'drivetrain_4WD'),
#  (0.019251057818901452, 'vehicle_type_Car'),
#  (0.01879059644377965, 'engine_block_I'),
#  (0.01863590556202437, 'engine_block_V'),
#  (0.014348940136034072, 'body_type_SUV'),
#  (0.014082075848076107, 'body_type_Pickup'),
#  (0.013806404210756112, 'body_type_Sedan'),
#  (0.013086902831347386, 'make_Ford'),
#  (0.012257244461205925, 'drivetrain_RWD'),
#  (0.010725164564818406, 'make_Toyota'),
#  (0.010171231708228853, 'trim_Base'),
#  (0.009438909013036732, 'vehicle_type_Truck'),
#  (0.008440975221331417, 'make_Chevrolet'),
#  (0.008055329312603941, 'body_type_Coupe'),
#  (0.007955549717967515, 'trim_SE'),
#  (0.007817946034557679, 'make_Nissan'),
#  (0.0072642182529823775, 'fuel_type_E85 / Unleaded'),
#  (0.00724026447588758, 'make_Mercedes-Benz'),
#  (0.007105309693606785, 'transmission_Automatic'),
#  (0.007087527716700621, 'make_Honda'),
#  (0.006919383460280604, 'fuel_type_Diesel'),
#  (0.006279489412170497, 'transmission_Manual'),
#  (0.005969591842794936, 'model_Range Rover'),
#  (0.0058451183161503115, 'trim_Limited'),
#  (0.005807901530488092, 'trim_XLT'),
#  (0.005406613682826543, 'trim_EX'),
#  (0.005368562406349836, 'trim_S'),
#  (0.005252021368522657, 'make_Jeep'),
#  (0.005202671255536809, 'make_Hyundai'),
#  (0.005178846415625287, 'trim_LX'),
#  (0.005148246453605746, 'make_RAM'),
#  (0.004840387990434954, 'make_Kia'),
#  (0.004555166137127514, 'body_type_Hatchback'),
#  (0.004331041254059586, 'make_BMW'),
#  (0.004326511448769571, 'make_Volkswagen'),
#  (0.0041636701307822075, 'make_Land Rover'),
#  (0.004096058649385845, 'trim_LE'),
#  (0.0040895961178385775, 'model_F-150'),
#  (0.00391832543101604, 'body_type_Crossover'),
#  (0.003847439083686245, 'trim_SV'),
#  (0.0035191122013575765, 'trim_LT'),
#  (0.003504442458484943, 'make_INFINITI'),
#  (0.003464352251444885, 'model_Impala'),
#  (0.0033465953298723265, 'trim_Sport'),
#  (0.003277227156817903, 'make_Dodge'),
#  (0.0032639373499235595, 'make_GMC'),
#  (0.0031280368662176265, 'engine_block_H'),
#  (0.0031277202206003796, 'fuel_type_Electric / Unleaded'),
#  (0.003108521179054398, 'model_Sentra'),
#  (0.0030999093586662413, 'trim_Lariat'),
#  (0.0030751653115755275, 'body_type_Minivan'),
#  (0.003058263638239082, 'trim_LS'),
#  (0.0029801157404263324, 'model_F-250 Super Duty'),
#  (0.0029600831192532965, 'make_Cadillac'),
#  (0.0028215758254013495, 'model_Accord'),
#  (0.0028147224975877084, 'model_Silverado 1500'),
#  (0.0027787647673582767, 'trim_2.0'),
#  (0.0027165774836766915, 'model_Camry'),
#  (0.0026814949548984906, 'trim_LAREDO'),
#  (0.0026793521629933483, 'model_Expedition'),
#  (0.002616442926894334, 'make_Lexus'),
#  (0.002607305173287851, 'model_911'),
#  (0.002592535301023327, 'trim_TRX'),
#  (0.0025815529870584285, 'model_Tucson'),
#  (0.0025692366159474757, 'model_Versa Sedan'),
#  (0.00254042337838584, 'model_CR-V'),
#  (0.002536270438064395, 'model_Edge'),
#  (0.002531657955990094, 'trim_SL'),
#  (0.0025305488757351585, 'trim_1LT'),
#  (0.002450194945079968, 'make_Chrysler'),
#  (0.002434125910967559, 'body_type_Wagon'),
#  (0.0023613299898027295, 'trim_EX-L'),
#  (0.0022583216903434254, 'make_Buick'),
#  (0.0022549884713921843, 'make_Audi'),
#  (0.0021505771987299243, 'trim_Premium'),
#  (0.0021279170457585393, 'trim_SEL'),
#  (0.002116497730331296, 'model_Ram 1500 Pickup'),
#  (0.0021142386337087045, 'model_Corolla'),
#  (0.002064529628482927, 'make_Subaru'),
#  (0.00203197590578465, 'model_Grand Cherokee'),
#  (0.0020138148199219568, 'fuel_type_Electric / Premium Unleaded'),
#  (0.002000437730548357, 'make_Mazda'),
#  (0.001972041895259579, 'make_Saturn'),
#  (0.0019716206229061835, 'body_type_Convertible'),
#  (0.001963034696413075, 'trim_350'),
#  (0.001954255258804615, 'model_Escape'),
#  (0.001911819727146839, 'model_MAZDA6'),
#  (0.0018881733383056718, 'make_Porsche'),
#  (0.0018842167334018058, 'model_300'),
#  (0.0018774474928863914, 'model_RAV4'),
#  (0.0018681131895235382, 'trim_LTZ'),
#  (0.0018446636386543077, 'model_Trax'),
#  (0.0018412581695782953, 'model_Jetta'),
#  (0.0018374308379837086, 'model_Pilot'),
#  (0.001792638870093561, 'model_Suburban'),
#  (0.0017864185053810427, 'trim_3LT'),
#  (0.0017648034007392457, 'model_Civic'),
#  (0.0017552162262517983, 'model_Spark'),
#  (0.00172959076134413, 'make_Maserati'),
#  (0.0016851932078756316, 'model_Sonata'),
#  (0.001684586489712873, 'trim_GLS'),
#  (0.0016828735032386685, 'model_M5'),
#  (0.001678025481165584, 'model_Rogue'),
#  (0.0016706361406516235, 'make_Ferrari'),
#  (0.0016604321367543456, 'trim_Autobiography'),
#  (0.0016488528834782226, 'model_Fusion'),
#  (0.001647390501785777, 'model_Explorer'),
#  (0.0016463613851305358, 'trim_2LT'),
#  (0.0016399490292997832, 'make_Acura'),
#  (0.0016334512955506065, 'trim_Latitude'),
#  (0.0016332417344557004, 'model_Cruze'),
#  (0.0016262807153849938, 'model_Sorento'),
#  (0.0016109529640856775, 'model_Passat'),
#  (0.0016022133797064047, 'model_G-Class'),
#  (0.0015761121338392597, 'trim_LTD'),
#  (0.0015687451975057033, 'trim_GL'),
#  (0.0015341531516102796, 'trim_Touring'),
#  (0.0015200485118386348, 'make_Lincoln'),
#  (0.0015052248989683365, 'trim_Westminster'),
#  (0.0014889096358376274, 'model_Cherokee'),
#  (0.0014581547539073581, 'make_Bentley'),
#  (0.001457740580721137, 'model_Journey'),
#  (0.0014540106894338884, 'trim_XLE'),
#  (0.0014476623346819043, 'trim_AMGA G63'),
#  (0.0014375531510477922, 'model_Grand Prix'),
#  (0.0014017720546713084, 'model_Equinox'),
#  (0.0013960686635556753, 'trim_Rubicon'),
#  (0.0013670124879697897, 'make_Jaguar'),
#  (0.0013662180203357465, 'model_Optima'),
#  (0.0013495844491125755, 'trim_V8'),
#  (0.0013350426079735737, 'trim_GTS GranSport'),
#  (0.0013201634860577263, 'trim_Platinum'),
#  (0.0013123101385612108, 'model_G'),
#  (0.0012564604370187283, 'model_Sportage'),
#  (0.0012473810210665234, 'trim_E350'),
#  (0.0012406327442153681, 'model_MKX'),
#  (0.0011979455094948228, 'model_AMG GT 4-Door Coupe'),
#  (0.0011764786791345844, 'trim_XE'),
#  (0.0011698581050443625, 'model_Sierra 1500 Denali'),
#  (0.0011410520024421767, 'model_Charger'),
#  (0.001137860302453904, 'model_E-Class'),
#  (0.0011319586055236139, 'model_812'),
#  (0.0011260662985083042, 'model_Tundra'),
#  (0.0011240358569098556, 'model_Taurus'),
#  (0.0010816545508425671, 'model_Traverse'),
#  (0.0010543151243403758, 'model_Montero'),
#  (0.0010537230763256068, 'model_S-Class'),
#  (0.0010518637092378135, 'trim_SXT'),
#  (0.0010497771463581296, 'model_Sedona'),
#  (0.0010469396789408872, 'trim_63'),
#  (0.0010407316584255134, 'model_Altima'),
#  (0.0010375322819518023, 'trim_SR5'),
#  (0.0010255113028643794, 'trim_Titanium'),
#  (0.0010224575024000782, 'trim_Big Horn'),
#  (0.001009157991511489, 'model_Wrangler Unlimited'),
#  (0.0010076275816958723, 'body_type_Targa'),
#  (0.0010002097771886589, 'model_Silverado 2500HD'),
#  (0.000990547435751364, 'trim_GP'),
#  (0.000988048102818273, 'model_Compass'),
#  (0.0009829557925561047, 'trim_Denali'),
#  (0.0009774235016348934, 'trim_SLT'),
#  (0.0009756496111829073, 'model_Corvette'),
#  (0.0009735737572817715, 'model_Forte'),
#  (0.0009479759789021182, 'model_Elantra'),
#  (0.0009469387771224363, 'model_Quattroporte'),
#  (0.0009416749360934507, 'model_Continental GT'),
#  (0.0009380923792123153, 'make_McLaren'),
#  (0.0009352557573554877, 'trim_37'),
#  (0.0009243272082403599, 'model_Macan'),
#  (0.0009224322042642563, 'trim_Premium Plus'),
#  (0.0009152085478396726, 'model_Malibu'),
#  (0.0009142859253375346, 'make_Pontiac'),
#  (0.0009043233607017155, 'model_Odyssey'),
#  (0.0009019747619634729, 'model_F-350 Super Duty'),
#  (0.0008943549784000098, 'model_Tahoe'),
#  (0.0008937989310612253, 'model_VUE'),
#  (0.0008905630644515417, 'make_Volvo'),
#  (0.0008767596041034055, 'trim_GLE350'),
#  (0.0008627684641775068, 'trim_40i'),
#  (0.0008585613675284401, 'model_RX'),
#  (0.000849337448471021, 'model_X5'),
#  (0.0008485492186016735, 'trim_Turbo S'),
#  (0.0008472106834325972, 'model_Cayenne'),
#  (0.0008312403814850891, 'model_Terrain'),
#  (0.000828121363752739, 'model_LaCrosse'),
#  (0.0008195864416710101, 'trim_30i'),
#  (0.0008149767266663797, 'model_Impreza'),
#  (0.0008014270046445298, 'make_Mitsubishi'),
#  (0.0007978817820278859, 'trim_SLE'),
#  (0.0007932879019113551, 'trim_Overland'),
#  (0.0007832675262612209, 'trim_XL'),
#  (0.0007822535953347603, 'body_type_Roadster'),
#  (0.000778441516961193, 'model_4Runner'),
#  (0.0007458261937372462, 'trim_C300'),
#  (0.0007378936423677245, 'trim_Reserve'),
#  (0.0007127224835599733, 'model_Navigator'),
#  (0.000712031381080643, 'model_200'),
#  (0.0007098144826059908, 'trim_V6'),
#  (0.00068030796448328, 'model_Colorado'),
#  (0.0006779989844365898, 'model_Envision'),
#  (0.000675331309902294, 'model_Rav4'),
#  (0.0006670180475445393, 'trim_Turbo'),
#  (0.0006665250457397543, 'model_Escalade ESV'),
#  (0.0006581031327179463, 'model_Prius'),
#  (0.0006516655207175623, 'model_Continental'),
#  (0.0006479850398256995, 'trim_High Country'),
#  (0.0006431740653665508, 'trim_HSE'),
#  (0.0006342004314169497, 'model_Fit'),
#  (0.0006288115114823093, 'trim_PreRunner'),
#  (0.0006228850519514121, 'model_xB'),
#  (0.0006167584576551381, 'model_ES'),
#  (0.0006142068608715035, 'model_Outback'),
#  (0.0006135447651104182, 'trim_L'),
#  (0.000610972507361863, 'trim_2LZ'),
#  (0.0006051989535557692, 'model_GX'),
#  (0.0006042670610987551, 'trim_AT4'),
#  (0.0006012500053221004, 'trim_SL500'),
#  (0.0005996924763489369, 'trim_330'),
#  (0.0005932652562711716, 'model_Mirage'),
#  (0.000592417807141733, 'trim_S GranSport'),
#  (0.0005901610578827441, 'model_4 Series'),
#  (0.0005859634910603606, 'model_Mazda3'),
#  (0.0005819280447367667, 'trim_GT Premium'),
#  (0.000579131751721736, 'model_X1'),
#  (0.0005712170726372566, 'model_Patriot'),
#  (0.0005538421946247476, 'model_5 Series'),
#  (0.0005510759236703205, 'model_MDX'),
#  (0.0005494143148689512, 'model_Santa Fe'),
#  (0.000549407732987916, 'trim_Work Truck'),
#  (0.0005482460411085534, 'model_QX80'),
#  (0.0005467435707487723, 'trim_Rebel'),
#  (0.0005448435210457438, 'model_S-Type'),
#  (0.000544805455945612, 'model_3 Series'),
#  (0.0005437799458762973, 'trim_Grand Touring'),
#  (0.0005279814501202162, 'trim_i'),
#  (0.0005279059806733886, 'trim_M235i'),
#  (0.0005241519610401024, 'trim_SES'),
#  (0.0005237093879863049, 'trim_Laramie'),
#  (0.0005209240202894795, 'model_All-New Wrangler Unlimited'),
#  (0.0005193582536520594, 'trim_xDrive28i'),
#  (0.0005159816838510313, 'model_Maxima'),
#  (0.0005063587900800717, 'model_Challenger'),
#  (0.0004981621848362312, 'trim_Sahara'),
#  (0.0004965375954989126, 'model_XT6'),
#  (0.0004900852950615152, 'trim_M550i'),
#  (0.00048720568919543796, 'trim_C300 Luxury'),
#  (0.0004829558901868021, 'model_RDX'),
#  (0.000477604124701013, 'model_Enclave'),
#  (0.0004743264726780483, 'model_Town Car'),
#  (0.00047292598112270247, 'model_S5 Coupe'),
#  (0.0004714944375041373, 'model_Ram 2500 Pickup'),
#  (0.00046565140538068467, 'model_Ram 3500 Pickup'),
#  (0.00046307885956105315, 'trim_Luxury'),
#  (0.0004628521383739602, 'trim_Premium Collection'),
#  (0.0004622594529227092, 'model_Camry Solara'),
#  (0.0004550196480140749, 'trim_340i'),
#  (0.0004468510360580844, 'model_TLX'),
#  (0.0004412411434155876, 'model_Veracruz'),
#  (0.0004402910228576018, 'model_R8'),
#  (0.00043431969733288313, 'model_XJ Series'),
#  (0.0004327807874157784, 'model_Acadia'),
#  (0.0004317244224422441, 'model_F-350 Super Duty Chassis Cab'),
#  (0.00043101720368576374, 'model_Mustang'),
#  (0.00043030341944552464, 'trim_Momentum'),
#  (0.00042647551564748977, 'trim_Technology Package'),
#  (0.0004261686557632385, 'model_7 Series'),
#  (0.00042453426675174836, 'model_Outlander'),
#  (0.00042268281043710167, 'trim_S560'),
#  (0.0004224920247488284, 'model_Pathfinder'),
#  (0.00041943291145757366, 'model_Frontier'),
#  (0.0004176400310244681, 'make_MINI'),
#  (0.0004161264779876693, 'model_Soul'),
#  (0.0004135337269271752, 'model_Accent'),
#  (0.00040833947030656807, 'trim_Warlock'),
#  (0.00040792368274030866, 'trim_Summit'),
#  (0.0004045113246469968, 'model_Gladiator'),
#  (0.0004035285869309064, 'model_HR-V'),
#  (0.0004014044229649032, 'model_570S'),
#  (0.00039636133181428945, 'model_Town & Country'),
#  (0.00039463655732959103, 'model_Murano'),
#  (0.00038536636418808897, 'model_Focus'),
#  (0.0003818468756943265, 'model_Telluride'),
#  (0.0003815800940567014, 'trim_Trailhawk'),
#  (0.0003806505128223899, 'trim_2LS'),
#  (0.00037742301484570967, 'model_Xterra'),
#  (0.00037669158601410423, 'model_Versa Note'),
#  (0.00037349813522583877, 'trim_LT1'),
#  (0.0003733493500364666, 'trim_E450'),
#  (0.00037132391329500967, 'trim_330i'),
#  (0.0003663656837068421, 'model_Caliber'),
#  (0.000365343027638745, 'trim_King Ranch'),
#  (0.00036433905620533003, 'model_Tiguan'),
#  (0.0003617581387323052, 'model_X2'),
#  (0.0003613245420576893, 'model_CLA-Class'),
#  (0.00036073898244827073, 'model_A6'),
#  (0.0003547518635693965, 'trim_SE Nightshade'),
#  (0.00035325901911148586, 'model_Fusion Hybrid'),
#  (0.0003476160047693625, 'trim_Four'),
#  (0.0003459748474876127, 'model_SRX'),
#  (0.000343899593903225, 'model_Blazer'),
#  (0.00033948465220350776, 'model_Q50'),
#  (0.00033910070451719903, 'trim_XSE'),
#  (0.00033849169688040804, 'model_IS'),
#  (0.0003351136953765294, 'trim_Heat'),
#  (0.00033360713631592554, 'trim_i Sport'),
#  (0.0003318627538782386, 'trim_530i'),
#  (0.0003311742320083379, 'trim_EX-L V6'),
#  (0.00033076976106109405, 'model_Outlander Sport'),
#  (0.0003266000344495313, 'trim_Exclaim'),
#  (0.00032606629063945686, 'model_Range Rover Evoque'),
#  (0.0003251935882482586, 'make_Scion'),
#  (0.00032515994139811733, 'trim_TRD Pro'),
#  (0.00032211499156114203, 'trim_CXL'),
#  (0.00032121408021597834, 'model_X3'),
#  (0.0003211003745128374, 'trim_S450'),
#  (0.00032057572783774946, 'model_Giulia'),
#  (0.0003184665287749508, 'trim_Touring-L'),
#  (0.0003178815758433598, 'model_Canyon'),
#  (0.00031677096352400095, 'trim_I Limited'),
#  (0.00031515500317028317, 'make_Hummer'),
#  (0.00031066874894990806, 'trim_SR'),
#  (0.0003106116736642792, 'trim_Signature Edition'),
#  (0.0003104449522833943, 'trim_R/T'),
#  (0.0003075690047275248, 'model_X7'),
#  (0.0003063475802335459, 'trim_VP'),
#  (0.000304917911370614, 'model_Highlander'),
#  (0.00030413525574354264, 'model_Pacifica'),
#  (0.00030376110376110376, 'model_Panamera'),
#  (0.00030299667036625967, 'trim_RS'),
#  (0.0003019988203920459, 'trim_xDrive50i'),
#  (0.0002993592982650872, 'trim_Wolfsburg Edition'),
#  (0.0002936181160038503, 'trim_Premium Luxury'),
#  (0.0002920622714926007, 'model_Sienna'),
#  (0.0002920090917994148, 'model_Rio 5-Door'),
#  (0.0002864284373047468, 'trim_Tradesman'),
#  (0.00028118378158109206, 'trim_SE w/Tech'),
#  (0.0002789684904091891, 'model_Sierra 2500HD'),
#  (0.00027659346883075547, 'trim_Express'),
#  (0.0002763323482193823, 'trim_Laredo E'),
#  (0.00027514861773378103, 'model_Yukon XL'),
#  (0.0002747532620259382, 'model_QX60'),
#  (0.0002710473120629369, 'model_GTO'),
#  (0.00026350087408433633, 'model_Yukon'),
#  (0.00026267905814486895, 'trim_Two'),
#  (0.00026244984658956835, 'fuel_type_E85 / Premium Unleaded'),
#  (0.00026123000916982754, 'model_Silverado 3500'),
#  (0.00026054833278825847, 'trim_Police'),
#  (0.0002601427443180162, 'trim_Limited Platinum'),
#  (0.00025982185557149677, 'model_Liberty'),
#  (0.00025705388870571864, 'model_XV Crosstrek'),
#  (0.0002536024624771866, 'model_Q5'),
#  (0.0002525781370603065, 'model_Kona'),
#  (0.0002496935523412602, 'trim_i Limited'),
#  (0.00024642960315320283, 'trim_LE Premium'),
#  (0.0002454022988505747, 'make_FIAT'),
#  (0.00024378109452736317, 'trim_Sport Touring'),
#  (0.0002432365351203772, 'trim_328i'),
#  (0.00024227774450243857, 'model_2 Series'),
#  (0.00024172656963324907, 'trim_RST'),
#  (0.0002397260273972603, 'trim_2.0I'),
#  (0.00023972602739726027, 'model_M4 Coupe'),
#  (0.00023908270309831665, 'trim_SLT1'),
#  (0.00023904921631838169, 'model_Element'),
#  (0.00023767892882340088, 'model_Silverado 3500HD'),
#  (0.0002375951530984595, 'trim_3.0i'),
#  (0.00023636929283031252, 'model_Camaro'),
#  (0.000236087205966724, 'model_500X'),
#  (0.0002348935745174674, 'model_LS'),
#  (0.00023139553818596302, 'model_Sonata Hybrid'),
#  (0.0002284352390098582, 'trim_Ti'),
#  (0.00022679560294239196, 'trim_Laredo'),
#  (0.00022482323633994813, 'trim_ES'),
#  (0.00022412807318467697, 'model_GLC-Class'),
#  (0.00022081396986339954, 'model_Captiva Sport'),
#  (0.00021957460725015074, 'model_Encore'),
#  (0.00021914858232608504, 'trim_750i'),
#  (0.00021701821402867743, 'trim_E300'),
#  (0.00021236253318164582, 'trim_Luxury Collection'),
#  (0.00020841866311918617, 'model_MAZDA3'),
#  (0.00020543713314797644, 'model_F-Pace'),
#  (0.00020454276878076785, 'model_Armada'),
#  (0.0002035268139195928, 'trim_CX'),
#  (0.00020070451380355537, 'trim_Tundra Grade'),
#  (0.00020021247037672635, 'trim_SRT'),
#  (0.0001999380388541731, 'trim_Sport S'),
#  (0.0001974841231069859, 'model_Prius Plug-In'),
#  (0.00019678025659883945, 'model_S4'),
#  (0.00019628396921974898, 'model_Mirage G4'),
#  (0.00019564010528915873, 'trim_xDrive35i'),
#  (0.00019311523437499995, 'model_Forte Koup'),
#  (0.00019270891046658075, 'trim_Preferred'),
#  (0.0001922517964313588, 'trim_2.5i Premium'),
#  (0.0001833374906460464, 'trim_X'),
#  (0.00018251800347653338, 'trim_E400'),
#  (0.00018201300842250406, 'trim_XJR'),
#  (0.00018103448275862068, 'model_XT5'),
#  (0.00018050098231827113, 'model_Levante'),
#  (0.00017815764482431148, 'model_Avalon'),
#  (0.00017801842052316442, 'model_Altima Sedan'),
#  (0.00017734470158343478, 'model_Dart'),
#  (0.00017613712090878235, 'trim_i Touring'),
#  (0.00017535174243316564, 'model_GS'),
#  (0.00017361457122294185, 'trim_2.5i Limited'),
#  (0.0001722847570684469, 'model_Express Cargo'),
#  (0.00017153124573314384, 'model_GL-Class'),
#  (0.00017022059648571605, 'model_GLK-Class'),
#  (0.0001685913423727988, 'trim_GT'),
#  (0.0001638244883835405, 'model_LeSabre'),
#  (0.00016243991380739266, 'trim_AMG® GLE43'),
#  (0.00016107823800131496, 'model_Fusion Energi'),
#  (0.00016064257028112453, 'model_Supra'),
#  (0.00016060308095706326, 'trim_xDrive30i'),
#  (0.0001604847293867191, 'trim_s Sport'),
#  (0.00016041864032119833, 'trim_Abarth'),
#  (0.00016032719836400815, 'trim_C250 Sport'),
#  (0.00016005226196308997, 'model_Discovery Sport'),
#  (0.00016000888607172053, 'body_type_Cargo Van'),
#  (0.00015989557839778107, 'model_FR-S'),
#  (0.00015985645542777917, 'trim_LIMITED'),
#  (0.00015938846873221108, 'model_Sierra 3500HD'),
#  (0.00015934959349593502, 'trim_First Edition'),
#  (0.00015927189988623435, 'fuel_type_E85 / Unleaded; Unleaded'),
#  (0.00015900933624791102, 'trim_I Premium'),
#  (0.00015808321414360804, 'trim_X Limited'),
#  (0.00015735862311204785, 'model_Wrangler'),
#  (0.0001571887950363947, 'model_Sonic'),
#  (0.00015691158156911573, 'model_CL-Class'),
#  (0.00015685538592520113, 'model_Renegade'),
#  (0.00015589818893783658, 'trim_200t'),
#  (0.0001554796192335856, 'trim_AMG® E63'),
#  (0.00015536585365853668, 'model_Clubman'),
#  (0.0001553602548486838, 'model_X6'),
#  (0.00015475313190862198, 'trim_T5 Premier'),
#  (0.00015277437029767734, 'model_Ghibli'),
#  (0.0001515064580703565, 'trim_Touring L'),
#  (0.00014907711185319723, 'trim_LX-P'),
#  (0.00014797708398099212, 'model_Aura'),
#  (0.0001467305809084661, 'trim_Altitude'),
#  (0.00014496221377500236, 'trim_Premier'),
#  (0.00014458689458689462, 'model_XE'),
#  (0.00014213492458146857, 'trim_GLI Autobahn'),
#  (0.00014164188965972913, 'trim_350 F SPORT'),
#  (0.00013923421183490803, 'trim_LXS'),
#  (0.00013829814706673734, 'trim_300'),
#  (0.00013509787703336107, 'model_C-HR'),
#  (0.0001348885766693988, 'trim_GLK350'),
#  (0.00013331684392777634, 'make_smart'),
#  (0.00013324709942314704, 'model_Durango'),
#  (0.00013098195065408219, 'trim_Si'),
#  (0.00012804770540526922, 'model_Range Rover Velar'),
#  (0.00012757302090960865, 'model_Titan'),
#  (0.00012668660741578747, 'trim_Performance Collection'),
#  (0.00012158808933002481, 'model_Tacoma'),
#  (0.0001214073339940535, 'trim_Ti Sport'),
#  (0.00012128712871287127, 'trim_Longhorn'),
#  (0.00012101753519387501, 'trim_Prestige'),
#  (0.00012045231071779743, 'trim_535i'),
#  (0.00012033398821218075, 'trim_LT Z71'),
#  (0.00012033398821218073, 'model_Aviator'),
#  (0.00012024539877300611, 'trim_Signature'),
#  (0.00012021589793915603, 'model_Crosstrek'),
#  (0.00012012748222603577, 'trim_1LS'),
#  (0.00012009803921568627, 'model_Z4'),
#  (0.00012009803921568627, 'model_A4'),
#  (0.00011986301369863015, 'trim_GT2'),
#  (0.00011986301369863014, 'trim_RTL-T'),
#  (0.00011937057475990196, 'trim_Signature Limited'),
#  (0.00011936662606577346, 'trim_Standard'),
#  (0.00011655188897834443, 'fuel_type_E85 / Unleaded; Unleaded / Unleaded'),
#  (0.00011630588107638877, 'trim_Big Horn/Lone Star'),
#  (0.00011302398288699604, 'model_C-Max'),
#  (0.00011170060516846587, 'model_tC'),
#  (0.0001111316496714535, 'model_Mazda2'),
#  (0.00010426385137899993, 'model_CTS'),
#  (0.00010094205157899435, 'trim_CE'),
#  (0.00010001660026560446, 'model_TrailBlazer'),
#  (9.99621991683817e-05, 'model_C-Class Sedan'),
#  (9.987912113957948e-05, 'trim_3.7'),
#  (9.954493742889655e-05, 'trim_Latitude Plus'),
#  (9.743673558333958e-05, 'trim_TRD Sport'),
#  (9.719281586413829e-05, 'trim_PREMIUM'),
#  (9.698169223156852e-05, 'trim_CXL-2'),
#  (9.648688122685316e-05, 'trim_Advance Package'),
#  (9.603135717785397e-05, 'model_Range Rover Sport'),
#  (9.282014019181472e-05, 'model_SL-Class'),
#  (9.026095855364151e-05, 'trim_SLE-2'),
#  (8.806161745828003e-05, 'model_Q3'),
#  (8.719237779332622e-05, 'model_Golf SportWagen'),
#  (8.516582552271098e-05, 'model_Yaris'),
#  (8.479989819940205e-05, 'model_New Optima'),
#  (8.279929858122103e-05, 'model_Prius c'),
#  (8.259747669247027e-05, 'trim_Platinum Edition'),
#  (8.030154047853163e-05, 'model_GLE-Class'),
#  (7.984790874524721e-05, 'model_Sequoia'),
#  (7.979156489171143e-05, 'model_G70'),
#  (7.894201455437469e-05, 'model_Santa Fe Sport'),
#  (7.141335665198057e-05, 'trim_Value'),
#  (6.964236290328594e-05, 'trim_Value Edition'),
#  (6.915287725364296e-05, 'model_S60'),
#  (6.449558423913015e-05, 'trim_1SG'),
#  (6.381470491262784e-05, 'trim_PRO-4X'),
#  (6.355642937112587e-05, 'trim_Mainstreet'),
#  (6.07825643835113e-05, 'model_C-Class'),
#  (6.050876759693751e-05, 'model_XC60'),
#  (6.015222194942302e-05, 'model_Kicks'),
#  (5.9931506849315074e-05, 'model_Forester'),
#  (5.6169655285351694e-05, 'trim_50i'),
#  (5.6057575474343534e-05, 'trim_EcoBoost Premium'),
#  (5.5288856064335986e-05, 'fuel_type_Unleaded / Unleaded'),
#  (5.178791615289757e-05, 'trim_540i'),
#  (4.906654650369567e-05, 'trim_GT Deluxe'),
#  (4.0269559500328755e-05, 'model_Quest'),
#  (4.003267973856208e-05, 'trim_Inscription'),
#  (3.9934800325998366e-05, 'trim_X Premium Package'),
#  (3.9788875355257815e-05, 'model_MAZDA5'),
#  (3.613569321533927e-05, 'model_Sierra 1500'),
#  (3.487777209333365e-05, 'model_Spectra'),
#  (3.190104166666663e-05, 'model_Rio'),
#  (3.0031870556508945e-05, 'trim_CrossRoad Plus'),
#  (2.8978307666832152e-05, 'model_GLS-Class'),
#  (2.6223633846404335e-05, 'model_Atlas'),
#  (1.9894437677628918e-05, 'trim_Plus'),
#  (1.626826029216478e-05, 'model_MKC'),
#  (8.000653114540014e-06, 'trim_Elite'),
#  (3.3352391842957755e-06, 'trim_Leather'),
#  (0.0, 'trim_xDrive40e'),
#  (0.0, 'trim_xDrive35i Premium'),
#  (0.0, 'trim_xDrive35d'),
#  (0.0, 'trim_sDrive35i'),
#  (0.0, 'trim_sDrive28i'),
#  (0.0, 'trim_s Grand Touring'),
#  (0.0, 'trim_s'),
#  (0.0, 'trim_passion'),
#  (0.0, 'trim_i SV'),
#  (0.0, 'trim_i Premium'),
#  (0.0, 'trim_i Grand Touring'),
#  (0.0, 'trim_ZR2'),
#  (0.0, 'trim_Z71 LTZ'),
#  (0.0, 'trim_Z71'),
#  (0.0, 'trim_Z51'),
#  (0.0, 'trim_XT Touring'),
#  (0.0, 'trim_XT Limited'),
#  (0.0, 'trim_XLS'),
#  (0.0, 'trim_XLE Premium'),
#  (0.0, 'trim_XLE AWD-e'),
#  (0.0, 'trim_Work Van'),
#  (0.0, 'trim_Work Truck 1WT'),
#  (0.0, 'trim_Winter'),
#  (0.0, 'trim_Willys Wheeler'),
#  (0.0, 'trim_Upland'),
#  (0.0, 'trim_Trailhawk Elite'),
#  (0.0, 'trim_Touring-L Plus'),
#  (0.0, 'trim_Touring Plus'),
#  (0.0, 'trim_Touring L Plus'),
#  (0.0, 'trim_Touring Hybrid'),
#  (0.0, 'trim_Touring Elite'),
#  (0.0, 'trim_Three Touring'),
#  (0.0, 'trim_Three'),
#  (0.0, 'trim_Technology Plus'),
#  (0.0, 'trim_Technology & AcuraWatch Plus Package'),
#  (0.0, 'trim_Technology & A-Spec Package'),
#  (0.0, 'trim_Technology & A-Spec Pack RED'),
#  (0.0, 'trim_Technology & A-SPEC Packages'),
#  (0.0, 'trim_Technology'),
#  (0.0, 'trim_TSI'),
#  (0.0, 'trim_TRD Off Road'),
#  (0.0, 'trim_TDI'),
#  (0.0, 'trim_T5 Platinum'),
#  (0.0, 'trim_T5 Inscription'),
#  (0.0, 'trim_Supercharged'),
#  (0.0, 'trim_Sunroof'),
#  (0.0, 'trim_Sport SE'),
#  (0.0, 'trim_Silver Edition'),
#  (0.0, 'trim_Shelby GT500'),
#  (0.0, 'trim_Sensory'),
#  (0.0, 'trim_Select'),
#  (0.0, 'trim_Scat Pack'),
#  (0.0, 'trim_SXT Plus'),
#  (0.0, 'trim_SXL'),
#  (0.0, 'trim_SX Limited'),
#  (0.0, 'trim_SX'),
#  (0.0, 'trim_SVR'),
#  (0.0, 'trim_ST'),
#  (0.0, 'trim_SRT8'),
#  (0.0, 'trim_SR5 Premium'),
#  (0.0, 'trim_SR Turbo'),
#  (0.0, 'trim_SPORT'),
#  (0.0, 'trim_SLT2'),
#  (0.0, 'trim_SLT-2'),
#  (0.0, 'trim_SLT-1'),
#  (0.0, 'trim_SLT+'),
#  (0.0, 'trim_SLE1'),
#  (0.0, 'trim_SLE-1'),
#  (0.0, 'trim_SL550'),
#  (0.0, 'trim_SEL Premium'),
#  (0.0, 'trim_SEL Plus'),
#  (0.0, 'trim_SE R-Line'),
#  (0.0, 'trim_SE Luxury'),
#  (0.0, 'trim_SE 2WD'),
#  (0.0, 'trim_SC'),
#  (0.0, 'trim_SAHARA'),
#  (0.0, 'trim_S550'),
#  (0.0, 'trim_S Plus'),
#  (0.0, 'trim_S Line Premium'),
#  (0.0, 'trim_S Krom Edition'),
#  (0.0, 'trim_S E PHEV'),
#  (0.0, 'trim_Rubicon Recon'),
#  (0.0, 'trim_Rubicon Hard Rock'),
#  (0.0, 'trim_Release Series 10.0'),
#  (0.0, 'trim_Red Sport'),
#  (0.0, 'trim_Raptor'),
#  (0.0, 'trim_RTS'),
#  (0.0, 'trim_RTL-E'),
#  (0.0, 'trim_RT'),
#  (0.0, 'trim_RED SPORT'),
#  (0.0, 'trim_R-Line SEL'),
#  (0.0, 'trim_R-Line'),
#  (0.0, 'trim_R-Dynamic S'),
#  (0.0, 'trim_R-Design'),
#  (0.0, 'trim_R'),
#  (0.0, 'trim_Quadrifoglio'),
#  (0.0, 'trim_Pure Premium'),
#  (0.0, 'trim_Pure Plus'),
#  (0.0, 'trim_Pure'),
#  (0.0, 'trim_Pro-4X'),
#  (0.0, 'trim_Premium II'),
#  (0.0, 'trim_Premium I'),
#  (0.0, 'trim_Premium AWD'),
#  (0.0, 'trim_Premium 2'),
#  (0.0, 'trim_Premiere'),
#  (0.0, 'trim_Preferred II'),
#  (0.0, 'trim_Polestar'),
#  (0.0, 'trim_Plug-in Hybrid Limited'),
#  (0.0, 'trim_Oxford Edition'),
#  (0.0, 'trim_Outdoorsman'),
#  (0.0, 'trim_North Edition'),
#  (0.0, 'trim_Night'),
#  (0.0, 'trim_M850i'),
#  (0.0, 'trim_M6'),
#  (0.0, 'trim_M440i'),
#  (0.0, 'trim_M40i'),
#  (0.0, 'trim_M340i'),
#  (0.0, 'trim_M240i'),
#  (0.0, 'trim_M'),
#  (0.0, 'trim_Luxe'),
#  (0.0, 'trim_Lux'),
#  (0.0, 'trim_Lounge'),
#  (0.0, 'trim_Lone Star Silver'),
#  (0.0, 'trim_Limited Ultimate'),
#  (0.0, 'trim_Limited Sterling Edition'),
#  (0.0, 'trim_Limited Premium'),
#  (0.0, 'trim_Launch Edition'),
#  (0.0, 'trim_Latitude Lux'),
#  (0.0, 'trim_Laramie Longhorn'),
#  (0.0, 'trim_Laramie Limited'),
#  (0.0, 'trim_LUXURY'),
#  (0.0, 'trim_LUXE'),
#  (0.0, 'trim_LTZ Z71'),
#  (0.0, 'trim_LT3'),
#  (0.0, 'trim_LT Trail Boss'),
#  (0.0, 'trim_LE Special Edition'),
#  (0.0, 'trim_LE Plus'),
#  (0.0, 'trim_LE Hybrid'),
#  (0.0, 'trim_John Cooper Works'),
#  (0.0, 'trim_Jetta'),
#  (0.0, 'trim_Inscription Platinum'),
#  (0.0, 'trim_Indy 500'),
#  (0.0, 'trim_I'),
#  (0.0, 'trim_Hybrid Touring'),
#  (0.0, 'trim_Hybrid LUXE'),
#  (0.0, 'trim_Hybrid EX-L'),
#  (0.0, 'trim_Hybrid EX'),
#  (0.0, 'trim_Hybrid'),
#  (0.0, 'trim_High Altitude Edition'),
#  (0.0, 'trim_HSE Dynamic'),
#  (0.0, 'trim_H3'),
#  (0.0, 'trim_Grand Touring Reserve'),
#  (0.0, 'trim_GTS'),
#  (0.0, 'trim_GTI'),
#  (0.0, 'trim_GT1'),
#  (0.0, 'trim_GT Plus'),
#  (0.0, 'trim_GS'),
#  (0.0, 'trim_GLS450'),
#  (0.0, 'trim_GLI'),
#  (0.0, 'trim_GLE43 AMG®'),
#  (0.0, 'trim_GLC300'),
#  (0.0, 'trim_GLA250'),
#  (0.0, 'trim_GL550'),
#  (0.0, 'trim_GL450'),
#  (0.0, 'trim_G63 AMG®'),
#  (0.0, 'trim_Freedom'),
#  (0.0, 'trim_Fleet'),
#  (0.0, 'trim_FX4'),
#  (0.0, 'trim_FX2'),
#  (0.0, 'trim_FE'),
#  (0.0, 'trim_F Sport'),
#  (0.0, 'trim_F SPORT'),
#  (0.0, 'trim_Essential'),
#  (0.0, 'trim_Essence'),
#  (0.0, 'trim_Energi SEL'),
#  (0.0, 'trim_Elevation'),
#  (0.0, 'trim_EcoBoost'),
#  (0.0, 'trim_Eco'),
#  (0.0, 'trim_EX-L V-6'),
#  (0.0, 'trim_ECO'),
#  (0.0, 'trim_E350 Sport'),
#  (0.0, 'trim_E350 Luxury'),
#  (0.0, 'trim_Dynamic'),
#  (0.0, 'trim_Dune'),
#  (0.0, 'trim_DE'),
#  (0.0, 'trim_Custom'),
#  (0.0, 'trim_Crossroad'),
#  (0.0, 'trim_Crew'),
#  (0.0, 'trim_Countryman S'),
#  (0.0, 'trim_Club'),
#  (0.0, 'trim_Citadel'),
#  (0.0, 'trim_Carrera S'),
#  (0.0, 'trim_Carrera'),
#  (0.0, 'trim_CLS550'),
#  (0.0, 'trim_CLS400'),
#  (0.0, 'trim_CLA250'),
#  (0.0, 'trim_CL63 AMG'),
#  (0.0, 'trim_CL55'),
#  (0.0, 'trim_C350e'),
#  (0.0, 'trim_C300 Sport'),
#  (0.0, 'trim_C250 Luxury'),
#  (0.0, 'trim_C'),
#  (0.0, 'trim_Avenir'),
#  (0.0, 'trim_Altitude Package'),
#  (0.0, 'trim_Adventure'),
#  (0.0, 'trim_Advanced'),
#  (0.0, 'trim_Advance and Entertainment Package'),
#  (0.0, 'trim_AcuraWatch Plus Package'),
#  (0.0, 'trim_AMG® SLC43'),
#  (0.0, 'trim_AMG® GLE63'),
#  (0.0, 'trim_AMG® GLC63'),
#  (0.0, 'trim_AMG® GLC43'),
#  (0.0, 'trim_AMG® G63'),
#  (0.0, 'trim_AMG® C43'),
#  (0.0, 'trim_AMG GLA35'),
#  (0.0, 'trim_ALPINA B7'),
#  (0.0, 'trim_A220'),
#  (0.0, 'trim_740i'),
#  (0.0, 'trim_650i'),
#  (0.0, 'trim_640i'),
#  (0.0, 'trim_570'),
#  (0.0, 'trim_56'),
#  (0.0, 'trim_550i'),
#  (0.0, 'trim_530e'),
#  (0.0, 'trim_528i'),
#  (0.0, 'trim_500 F SPORT'),
#  (0.0, 'trim_500'),
#  (0.0, 'trim_460'),
#  (0.0, 'trim_450h'),
#  (0.0, 'trim_440i'),
#  (0.0, 'trim_435i'),
#  (0.0, 'trim_430i'),
#  (0.0, 'trim_428i'),
#  (0.0, 'trim_400 SPORT'),
#  (0.0, 'trim_37x'),
#  (0.0, 'trim_37 Journey'),
#  (0.0, 'trim_35 Journey'),
#  (0.0, 'trim_335i'),
#  (0.0, 'trim_330e'),
#  (0.0, 'trim_320i'),
#  (0.0, 'trim_300h F Sport Black Line AWD'),
#  (0.0, 'trim_300h'),
#  (0.0, 'trim_300 F SPORT'),
#  (0.0, 'trim_3.2'),
#  (0.0, 'trim_2SS'),
#  (0.0, 'trim_2LZ Premier'),
#  (0.0, 'trim_2FL'),
#  (0.0, 'trim_28i'),
#  (0.0, 'trim_250h F SPORT'),
#  (0.0, 'trim_250'),
#  (0.0, 'trim_230i'),
#  (0.0, 'trim_228i'),
#  (0.0, 'trim_2.5i'),
#  (0.0, 'trim_2.5'),
#  (0.0, 'trim_2.4i'),
#  (0.0, 'trim_2.0T Ultimate'),
#  (0.0, 'trim_2.0I Sport Premium'),
#  (0.0, 'trim_2.0I Premium'),
#  (0.0, 'trim_1SS'),
#  (0.0, 'trim_1SL'),
#  (0.0, 'trim_1SD'),
#  (0.0, 'trim_1SC'),
#  (0.0, 'trim_1SA'),
#  (0.0, 'trim_1FL'),
#  (0.0, 'trim_1794 Edition'),
#  (0.0, 'trim_+'),
#  (0.0, 'model_iA'),
#  (0.0, 'model_i3'),
#  (0.0, 'model_fortwo'),
#  (0.0, 'model_XTS'),
#  (0.0, 'model_XT4'),
#  (0.0, 'model_XF'),
#  (0.0, 'model_XC90'),
#  (0.0, 'model_XC40'),
#  (0.0, 'model_X5 M'),
#  (0.0, 'model_X4'),
#  (0.0, 'model_Wrangler JK Unlimited'),
#  (0.0, 'model_WRX STI'),
#  (0.0, 'model_WRX'),
#  (0.0, 'model_Volt'),
#  (0.0, 'model_Verano'),
#  (0.0, 'model_Venza'),
#  (0.0, 'model_Venue'),
#  (0.0, 'model_Veloster'),
#  (0.0, 'model_V50'),
#  (0.0, 'model_UX Hybrid'),
#  (0.0, 'model_Transit Wagon'),
#  (0.0, 'model_Transit Van'),
#  (0.0, 'model_Transit Passenger Van'),
#  (0.0, 'model_Transit Connect'),
#  (0.0, 'model_Transit'),
#  (0.0, 'model_Trailblazer'),
#  (0.0, 'model_Touareg'),
#  (0.0, 'model_Titan XD'),
#  (0.0, 'model_Tiguan Limited'),
#  (0.0, 'model_Taurus X'),
#  (0.0, 'model_TSX'),
#  (0.0, 'model_TL'),
#  (0.0, 'model_Stinger'),
#  (0.0, 'model_Stelvio'),
#  (0.0, 'model_Sonata Plug-In Hybrid'),
#  (0.0, 'model_Silverado 3500 Chassis Cab'),
#  (0.0, 'model_Silverado 1500 LD'),
#  (0.0, 'model_Silverado'),
#  (0.0, 'model_Sierra 2500 Denali HD'),
#  (0.0, 'model_Sebring'),
#  (0.0, 'model_Savana Cutaway'),
#  (0.0, 'model_Savana Cargo'),
#  (0.0, 'model_SQ5'),
#  (0.0, 'model_SLC Roadster'),
#  (0.0, 'model_S90'),
#  (0.0, 'model_S80'),
#  (0.0, 'model_S5 Sportback'),
#  (0.0, 'model_S3'),
#  (0.0, 'model_Rogue Sport'),
#  (0.0, 'model_Rogue Select'),
#  (0.0, 'model_Ridgeline'),
#  (0.0, 'model_Regal Sportback'),
#  (0.0, 'model_Regal'),
#  (0.0, 'model_Ranger'),
#  (0.0, 'model_Ram Pickup'),
#  (0.0, 'model_Ram 3500 Chassis Cab'),
#  (0.0, 'model_Ram 1500 Classic'),
#  (0.0, 'model_RLX'),
#  (0.0, 'model_RL'),
#  (0.0, 'model_RC F'),
#  (0.0, 'model_RC'),
#  (0.0, 'model_QX50'),
#  (0.0, 'model_QX30'),
#  (0.0, 'model_QX'),
#  (0.0, 'model_Q70'),
#  (0.0, 'model_Q7'),
#  (0.0, 'model_Q60 Coupe'),
#  (0.0, 'model_Q40'),
#  (0.0, 'model_Promaster City'),
#  (0.0, 'model_ProMaster Cargo Van'),
#  (0.0, 'model_Prius v'),
#  (0.0, 'model_Prius Prime'),
#  (0.0, 'model_Passport'),
#  (0.0, 'model_Palisade'),
#  (0.0, 'model_Pacifica Hybrid'),
#  (0.0, 'model_Niro'),
#  (0.0, 'model_Nautilus'),
#  (0.0, 'model_NX Hybrid'),
#  (0.0, 'model_NX'),
#  (0.0, 'model_NV200'),
#  (0.0, 'model_Matrix'),
#  (0.0, 'model_Malibu Limited'),
#  (0.0, 'model_MX-5 Miata RF'),
#  (0.0, 'model_MX-5 Miata'),
#  (0.0, 'model_MX-5'),
#  (0.0, 'model_MKZ'),
#  (0.0, 'model_MKT'),
#  (0.0, 'model_MINI'),
#  (0.0, 'model_M3 Sedan'),
#  (0.0, 'model_M'),
#  (0.0, 'model_Legacy'),
#  (0.0, 'model_Lancer'),
#  (0.0, 'model_LX'),
#  (0.0, 'model_LR2'),
#  (0.0, 'model_LC'),
#  (0.0, 'model_K900'),
#  (0.0, 'model_Jimmy'),
#  (0.0, 'model_JX'),
#  (0.0, 'model_JUKE'),
#  (0.0, 'model_Ioniq'),
#  (0.0, 'model_ILX'),
#  (0.0, 'model_Hardtop 2 Door'),
#  (0.0, 'model_HHR'),
#  (0.0, 'model_H3'),
#  (0.0, 'model_H1'),
#  (0.0, 'model_Grand Marquis'),
#  (0.0, 'model_Grand Caravan'),
#  (0.0, 'model_GranTurismo'),
#  (0.0, 'model_Golf GTI'),
#  (0.0, 'model_Golf'),
#  (0.0, 'model_Genesis Coupe'),
#  (0.0, 'model_GTI'),
#  (0.0, 'model_GLE-Class Coupe'),
#  (0.0, 'model_GLE'),
#  (0.0, 'model_GLC Coupe'),
#  (0.0, 'model_GLC'),
#  (0.0, 'model_GLB'),
#  (0.0, 'model_GLA-Class'),
#  (0.0, 'model_GLA'),
#  (0.0, 'model_G80'),
#  (0.0, 'model_G Sedan'),
#  (0.0, 'model_G Coupe'),
#  (0.0, 'model_Forte5'),
#  (0.0, 'model_Flex'),
#  (0.0, 'model_Fiesta'),
#  (0.0, 'model_FORTE'),
#  (0.0, 'model_FJ Cruiser'),
#  (0.0, 'model_F-Type'),
#  (0.0, 'model_F-TYPE'),
#  (0.0, 'model_F-PACE'),
#  (0.0, 'model_F-250'),
#  (0.0, 'model_Express Cutaway'),
#  (0.0, 'model_Express'),
#  (0.0, 'model_Escalade'),
#  (0.0, 'model_Equus'),
#  (0.0, 'model_Elantra GT'),
#  (0.0, 'model_Ecosport'),
#  (0.0, 'model_Eclipse Cross'),
#  (0.0, 'model_EX'),
#  (0.0, 'model_E-Series Cutaway'),
#  (0.0, 'model_E-PACE'),
#  (0.0, 'model_Discovery'),
#  (0.0, 'model_Defender'),
#  (0.0, 'model_DTS'),
#  (0.0, 'model_Cruze Limited'),
#  (0.0, 'model_Crown Victoria'),
#  (0.0, 'model_Crosstour'),
#  (0.0, 'model_Countryman'),
#  (0.0, 'model_Corolla iM'),
#  (0.0, 'model_Corolla Hatchback'),
#  (0.0, 'model_Cooper'),
#  (0.0, 'model_Civic Hatchback'),
#  (0.0, 'model_Cayman'),
#  (0.0, 'model_Cadenza'),
#  (0.0, 'model_CX-9'),
#  (0.0, 'model_CX-5'),
#  (0.0, 'model_CX-30'),
#  (0.0, 'model_CX-3'),
#  (0.0, 'model_CTS Sedan'),
#  (0.0, 'model_CT6'),
#  (0.0, 'model_CT5'),
#  (0.0, 'model_CT'),
#  (0.0, 'model_CLS-Class'),
#  (0.0, 'model_CLA'),
#  (0.0, 'model_CL Class'),
#  (0.0, 'model_CC'),
#  (0.0, 'model_C30'),
#  (0.0, 'model_C-Class Coupe'),
#  (0.0, 'model_C-Class Cabriolet'),
#  (0.0, 'model_Beetle'),
#  (0.0, 'model_Azera'),
#  (0.0, 'model_Avenger'),
#  (0.0, 'model_Avalanche'),
#  (0.0, 'model_Ascent'),
#  (0.0, 'model_Arteon'),
#  (0.0, 'model_All-New Wrangler'),
#  (0.0, 'model_Acadia Limited'),
#  (0.0, 'model_ATS Sedan'),
#  (0.0, 'model_ATS Coupe'),
#  (0.0, 'model_AMG GT Coupe'),
#  (0.0, 'model_A8'),
#  (0.0, 'model_A7'),
#  (0.0, 'model_A5 Sportback'),
#  (0.0, 'model_A5 Coupe'),
#  (0.0, 'model_A5 Cabriolet'),
#  (0.0, 'model_A5'),
#  (0.0, 'model_A3 Sportback e-tron'),
#  (0.0, 'model_A3 Sedan'),
#  (0.0, 'model_A-Class'),
#  (0.0, 'model_8 Series'),
#  (0.0, 'model_718'),
#  (0.0, 'model_6 Series Gran Turismo'),
#  (0.0, 'model_6 Series'),
#  (0.0, 'model_500L'),
#  (0.0, 'model_500'),
#  (0.0, 'model_370Z Coupe'),
#  (0.0, 'make_Mercury'),
#  (0.0, 'make_GENESIS'),
#  (0.0, 'make_Alfa Romeo'),
#  (0.0, 'fuel_type_Premium Unleaded; Unleaded'),
#  (0.0, 'fuel_type_Premium Unleaded / Unleaded'),
#  (0.0, 'fuel_type_E85'),
#  (0.0, 'body_type_Passenger Van'),
#  ...]

# %% [markdown]
# Looking at the feature importances we can see that year and miles has the most influence over price, which is then followed by enginesize, fuel type, and the drivetrain. This makes sense as the year and miles on a car play a big part in deciding if the car is worth what they are selling it for. While this model is informatiive, it doesn't answer the question of what make has most influence on price.

# %% [markdown]
# # BRFC Focused on Make
# The next model is a BRFC with the used car dataset, except this time the data is cleaned to focus on the make of the car. This means we drop some of the columns such as body_type, fuel_type and more, so the feature importances highlights the makes that influence price.

# %%
clean_df = pd.read_csv('make_model.csv')

# %%
clean_df = clean_df.drop(columns=['id', 'vin', 'body_type', 'vehicle_type', 'drivetrain', 'transmission', 'fuel_type', 'engine_size', 'engine_block'])

# %%
clean_df
# Out:
#            price     miles    year        make             model        trim
# 0        20998.0  115879.0  2015.0   Chevrolet     Express Cargo    Work Van
# 1        27921.0    7339.0  2018.0         BMW                i3           s
# 2        11055.0   39798.0  2018.0  Mitsubishi         Mirage G4          SE
# 3        52997.0   28568.0  2019.0   Chevrolet          Colorado         ZR2
# 4         3995.0  137537.0  2000.0       Dodge        Ram Pickup          ST
# ...          ...       ...     ...         ...               ...         ...
# 6167618  69900.0   15270.0  2019.0        Ford  F-250 Super Duty      Lariat
# 6167619  32991.0  143026.0  2011.0        Ford  F-250 Super Duty  King Ranch
# 6167620  82900.0    3686.0  2021.0        Ford  F-250 Super Duty  King Ranch
# 6167621  59995.0   39111.0  2019.0        Ford  F-250 Super Duty         XLT
# 6167622  74985.0   18486.0  2019.0        Ford  F-250 Super Duty      Lariat
#
# [6167623 rows x 6 columns]

# %%
clean_df['price'] = pd.cut(clean_df['price'], bins, labels=labels )

# %%
make_df = clean_df.sample(n=5000)

# %%
make_df
# Out:
#                  price     miles    year       make             model  \
# 3640542  15,000-24,999   35754.0  2020.0  Chevrolet           Equinox
# 2497573  25,000-49,999   43854.0  2017.0       Ford             F-150
# 1204748   10,000-14999   92725.0  2014.0      Dodge     Grand Caravan
# 4598761  50,000-99,999   51057.0  2019.0  Chevrolet  Silverado 2500HD
# 4062198  15,000-24,999  101787.0  2015.0       Jeep          Cherokee
# ...                ...       ...     ...        ...               ...
# 5941428  25,000-49,999   23471.0  2019.0        RAM   Ram 1500 Pickup
# 4547085  25,000-49,999   17064.0  2019.0        RAM   Ram 1500 Pickup
# 5826303  25,000-49,999   66600.0  2017.0      Dodge           Durango
# 3181381  15,000-24,999      13.0  2019.0       Ford          Ecosport
# 4206351   10,000-14999   60034.0  2011.0      Honda             Pilot
#
#                            trim
# 3640542                      LT
# 2497573                     XLT
# 1204748  American Value Package
# 4598761                     LTZ
# 4062198               Trailhawk
# ...                         ...
# 5941428      Big Horn/Lone Star
# 4547085      Big Horn/Lone Star
# 5826303                      GT
# 3181381                      SE
# 4206351                    EX-L
#
# [5000 rows x 6 columns]

# %%
X = pd.get_dummies(make_df)
X = X.drop(columns= ["price_0-4,999", "price_5,000-9,999", "price_10,000-14999", "price_15,000-24,999", "price_25,000-49,999", "price_50,000-99,999", "price_100,000-400,000"])
y = make_df['price']

# %%
X.describe()
# Out:
#                miles         year   make_Acura  make_Alfa Romeo  \
# count    5000.000000  5000.000000  5000.000000      5000.000000
# mean    52829.154400  2016.650000     0.014200         0.002000
# std     43278.869171     3.397324     0.118326         0.044681
# min         0.000000  1999.000000     0.000000         0.000000
# 25%     22893.750000  2015.000000     0.000000         0.000000
# 50%     39080.000000  2018.000000     0.000000         0.000000
# 75%     74024.750000  2019.000000     0.000000         0.000000
# max    310192.000000  2021.000000     1.000000         1.000000
#
#        make_Aston Martin    make_Audi     make_BMW  make_Bentley   make_Buick  \
# count        5000.000000  5000.000000  5000.000000   5000.000000  5000.000000
# mean            0.000200     0.016400     0.043400      0.000200     0.010400
# std             0.014142     0.127021     0.203776      0.014142     0.101459
# min             0.000000     0.000000     0.000000      0.000000     0.000000
# 25%             0.000000     0.000000     0.000000      0.000000     0.000000
# 50%             0.000000     0.000000     0.000000      0.000000     0.000000
# 75%             0.000000     0.000000     0.000000      0.000000     0.000000
# max             1.000000     1.000000     1.000000      1.000000     1.000000
#
#        make_Cadillac  ...  trim_s Grand Touring  trim_sDrive28i  \
# count    5000.000000  ...           5000.000000     5000.000000
# mean        0.011600  ...              0.000200        0.000200
# std         0.107088  ...              0.014142        0.014142
# min         0.000000  ...              0.000000        0.000000
# 25%         0.000000  ...              0.000000        0.000000
# 50%         0.000000  ...              0.000000        0.000000
# 75%         0.000000  ...              0.000000        0.000000
# max         1.000000  ...              1.000000        1.000000
#
#        trim_sDrive35i  trim_xDrive28d  trim_xDrive28i  trim_xDrive30i  \
# count      5000.00000     5000.000000     5000.000000     5000.000000
# mean          0.00060        0.000400        0.002000        0.002200
# std           0.02449        0.019998        0.044681        0.046857
# min           0.00000        0.000000        0.000000        0.000000
# 25%           0.00000        0.000000        0.000000        0.000000
# 50%           0.00000        0.000000        0.000000        0.000000
# 75%           0.00000        0.000000        0.000000        0.000000
# max           1.00000        1.000000        1.000000        1.000000
#
#        trim_xDrive35d  trim_xDrive35i  trim_xDrive40e  trim_xDrive50i
# count     5000.000000     5000.000000     5000.000000     5000.000000
# mean         0.000400        0.001600        0.000200        0.000400
# std          0.019998        0.039972        0.014142        0.019998
# min          0.000000        0.000000        0.000000        0.000000
# 25%          0.000000        0.000000        0.000000        0.000000
# 50%          0.000000        0.000000        0.000000        0.000000
# 75%          0.000000        0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
# [8 rows x 1018 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (3750, 1018)

# %%
clf = BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_train, y_train)

# %%
# Display the confusion matrix
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[  7,   1,   0,   0,   0,   2,   0],
#        [ 13,  67,   5,  25,   0,  51,   0],
#        [  0,   0,   4,   0,   0,   0,   0],
#        [  5,  87,  18, 223,  34,  25,  19],
#        [  1,  28,  55, 108, 214,   5,  91],
#        [ 19,  13,   2,   2,   0,  44,   0],
#        [  0,   2,  19,   1,  15,   0,  45]], dtype=int64)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5976862074672545

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                        pre       rec       spe        f1       geo       iba       sup
#
#         0-4,999       0.16      0.70      0.97      0.25      0.82      0.66        10
#    10,000-14999       0.34      0.42      0.88      0.37      0.61      0.35       161
# 100,000-400,000       0.04      1.00      0.92      0.07      0.96      0.93         4
#   15,000-24,999       0.62      0.54      0.84      0.58      0.67      0.44       411
#   25,000-49,999       0.81      0.43      0.93      0.56      0.63      0.38       502
#     5,000-9,999       0.35      0.55      0.93      0.43      0.71      0.49        80
#   50,000-99,999       0.29      0.55      0.91      0.38      0.71      0.48        82
#
#     avg / total       0.62      0.48      0.89      0.52      0.65      0.41      1250

# %%
# List the features sorted in descending order by feature importance
sorted(zip(clf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.13401994463029213, 'miles'),
#  (0.10974095002207085, 'year'),
#  (0.013500016278633791, 'make_Mercedes-Benz'),
#  (0.013495838209286935, 'trim_Base'),
#  (0.013052564631885337, 'make_Ford'),
#  (0.012485967247521308, 'make_Chevrolet'),
#  (0.011360106564712515, 'make_Honda'),
#  (0.011105330611009401, 'trim_SE'),
#  (0.010818506644296802, 'make_Toyota'),
#  (0.008669566867271508, 'make_Nissan'),
#  (0.008288536840559305, 'trim_LX'),
#  (0.00817759200931279, 'make_Jeep'),
#  (0.008161433613304556, 'make_BMW'),
#  (0.007863597820631849, 'trim_S'),
#  (0.007421946518717577, 'trim_Limited'),
#  (0.007300052485573562, 'make_GMC'),
#  (0.00729341133993624, 'make_Dodge'),
#  (0.007050083856341386, 'make_Porsche'),
#  (0.006740080701081175, 'model_911'),
#  (0.00673615821342588, 'model_F-150'),
#  (0.006359882481837229, 'make_Kia'),
#  (0.006162045566053071, 'make_Hyundai'),
#  (0.005636620295054441, 'make_RAM'),
#  (0.005545148768298139, 'trim_EX'),
#  (0.005513463798182704, 'trim_1LT'),
#  (0.005456654532010472, 'model_Ram 1500 Pickup'),
#  (0.005102155756065854, 'model_Viper'),
#  (0.00507466842831036, 'trim_XLT'),
#  (0.005042132685512069, 'model_Malibu'),
#  (0.005012735288928633, 'trim_LS'),
#  (0.004963964651909055, 'model_Fusion'),
#  (0.004785714085575052, 'trim_LE'),
#  (0.004628402796005865, 'trim_SV'),
#  (0.004590806042486918, 'model_Camry'),
#  (0.0045500080714573335, 'model_Explorer'),
#  (0.004509691336693262, 'trim_LT'),
#  (0.004471268679956026, 'model_Mustang'),
#  (0.004454214907242071, 'trim_Laramie'),
#  (0.004402844521674393, 'model_Escape'),
#  (0.004395110614634032, 'trim_Sport'),
#  (0.004394079188721903, 'make_Mazda'),
#  (0.004372412547063641, 'trim_SEL'),
#  (0.004328110952902289, 'trim_M'),
#  (0.004320459966875154, 'make_Cadillac'),
#  (0.004196141418157748, 'model_Sprinter Crew Van'),
#  (0.004163569325165793, 'model_Wrangler Unlimited'),
#  (0.004133034275918507, 'make_Volkswagen'),
#  (0.00412307077526377, 'make_Lexus'),
#  (0.004114045337554134, 'model_Silverado 1500'),
#  (0.004029468511556653, 'model_F-250 Super Duty'),
#  (0.003916800914172769, 'model_Corolla'),
#  (0.003915091744087533, 'make_Bentley'),
#  (0.0038857435972772603, 'model_Equinox'),
#  (0.0038496087634098362, 'model_Edge'),
#  (0.0038254490812672536, 'make_Chrysler'),
#  (0.0038196958902850147, 'model_Jetta'),
#  (0.003729332481769347, 'trim_LTZ'),
#  (0.0037253669362521764, 'model_AMG GT 4-Door Coupe'),
#  (0.003707315975976786, 'model_Corvette'),
#  (0.00362279086217556, 'trim_GTS'),
#  (0.0035938138864365483, 'model_DB11'),
#  (0.0035495252861350666, 'model_812'),
#  (0.0035169056123671282, 'model_Cruze'),
#  (0.0034924207240203085, 'trim_Shelby GT500'),
#  (0.0034495202928589634, 'model_Grand Cherokee'),
#  (0.0034396828028176374, 'make_Audi'),
#  (0.0034010859965427995, 'trim_Turbo'),
#  (0.003338711234572862, 'model_Bentayga'),
#  (0.0032513592491494104, 'model_Rogue'),
#  (0.003211777121742691, 'trim_SXT'),
#  (0.00319528517133788, 'trim_Lariat'),
#  (0.003175922108531931, 'make_INFINITI'),
#  (0.003145915462733737, 'make_Buick'),
#  (0.003139571448253069, 'model_Focus'),
#  (0.0029535121597406, 'trim_Denali'),
#  (0.002941773533525007, 'model_Tahoe'),
#  (0.0029375882949754816, 'make_Volvo'),
#  (0.0029370311596550436, 'make_Subaru'),
#  (0.002935643646177423, 'model_Accord'),
#  (0.002833173634537199, 'model_Elantra'),
#  (0.0027280743266687745, 'trim_Carrera S'),
#  (0.0027231061229155908, 'model_Civic'),
#  (0.0027179414614824844, 'model_Sonata'),
#  (0.0027117004089813046, 'model_CR-V'),
#  (0.0026841914761367384, 'trim_SL'),
#  (0.002668859686929986, 'model_Altima'),
#  (0.0026088683844516297, 'model_200'),
#  (0.0025976302779215045, 'trim_GT'),
#  (0.0025846230951335476, 'model_Sentra'),
#  (0.002577601124313268, 'trim_EX-L'),
#  (0.002538664727694777, 'trim_TRX'),
#  (0.0024928455702647474, 'model_Fiesta'),
#  (0.0024919363725144426, 'model_X5'),
#  (0.0024822912919636587, 'make_Ferrari'),
#  (0.0024645870237018194, 'model_Highlander'),
#  (0.002431602155124019, 'model_G-Class'),
#  (0.0023884653528273266, 'make_Lincoln'),
#  (0.002338518459717691, 'trim_Touring'),
#  (0.0023280861357747045, 'trim_Premium'),
#  (0.002323407846083064, 'trim_CLK63'),
#  (0.0022683583055828215, 'make_Aston Martin'),
#  (0.0022563204577205837, 'trim_350'),
#  (0.002231895380638508, 'model_Sierra 1500'),
#  (0.002209015007321543, 'make_Acura'),
#  (0.0021987999660303993, 'model_Taurus'),
#  (0.0021374019036802115, 'trim_Platinum'),
#  (0.002124676626801306, 'model_Traverse'),
#  (0.002117974861421823, 'trim_SLT'),
#  (0.0020846007093433395, 'trim_G550'),
#  (0.002055538717801821, 'trim_Sport S'),
#  (0.0020507454443977322, 'model_Compass'),
#  (0.0020406641415248237, 'model_3 Series'),
#  (0.002030345660906102, 'model_Ram 2500 Pickup'),
#  (0.0020144140085894984, 'model_SX4 Crossover'),
#  (0.0019893832518224487, 'model_Pilot'),
#  (0.0019850681544402848, 'model_Journey'),
#  (0.001954968631931064, 'trim_Reserve'),
#  (0.0019202006858952416, 'model_LeSabre'),
#  (0.0018978972168904485, 'model_F-350 Super Duty'),
#  (0.0018736643323883117, 'model_RAV4'),
#  (0.0018538070223355788, 'trim_328i'),
#  (0.001842509356584519, 'model_Odyssey'),
#  (0.0018412580633208806, 'trim_GLS'),
#  (0.0017947798027982214, 'model_Cobalt'),
#  (0.0017832768060557136, 'model_Santa Fe'),
#  (0.0017784301497127707, 'trim_XLE'),
#  (0.0017749538325776818, 'model_5 Series'),
#  (0.0017696347583176309, 'model_Charger'),
#  (0.001729704042681452, 'model_Grand Caravan'),
#  (0.0017273111290750974, 'trim_Luxury'),
#  (0.0016935239040341012, 'model_Forte'),
#  (0.001669366631836648, 'model_Terrain'),
#  (0.0016491782769331232, 'make_Land Rover'),
#  (0.0016465114463645957, 'trim_Premium Luxury'),
#  (0.0016453781604994391, 'model_Prius'),
#  (0.0016388759921700915, 'trim_XL'),
#  (0.0016380028793056653, 'model_Tribute'),
#  (0.0016333256002682662, 'trim_SR'),
#  (0.001618741255532854, 'trim_i Touring'),
#  (0.001534280218635784, 'trim_ST'),
#  (0.0015239742799323355, 'model_Tucson'),
#  (0.001514977152742289, 'model_Gladiator'),
#  (0.001513181123947923, 'trim_Big Horn/Lone Star'),
#  (0.0015110875426909468, 'trim_Technology Package'),
#  (0.0014799653886763459, 'trim_Premium Plus'),
#  (0.0014667087991896705, 'trim_GLS450'),
#  (0.0014590058137444997, 'trim_Big Horn'),
#  (0.0014411709947366764, 'model_Titan XD'),
#  (0.001435508428139938, 'model_Soul'),
#  (0.0014282965367961892, 'model_ES'),
#  (0.0014275105354780962, 'model_Acadia'),
#  (0.0014274100559910018, 'model_Expedition'),
#  (0.0013946633211531845, 'trim_63'),
#  (0.0013733521683120366, 'model_CLK-Class'),
#  (0.0013686403531423706, 'model_Aviator'),
#  (0.00136224958656399, 'model_Patriot'),
#  (0.0013610415541911857, 'model_Colorado'),
#  (0.0013442349708947163, 'trim_Prestige'),
#  (0.0013368413135542616, 'trim_L'),
#  (0.0013367862195129499, 'model_Challenger'),
#  (0.0013365413046506447, 'make_Mitsubishi'),
#  (0.0013343903740679777, 'trim_King Ranch'),
#  (0.001282333570528508, 'model_A4'),
#  (0.0012339873558113313, 'trim_CE'),
#  (0.0012331126880359205, 'trim_530i'),
#  (0.0012318126887068705, 'model_PT Cruiser'),
#  (0.0012301726427867813, 'trim_SLE'),
#  (0.00122787349479639, 'model_Range Rover Sport'),
#  (0.0012211425942613569, 'trim_Raptor'),
#  (0.0012144823476951995, 'make_Pontiac'),
#  (0.00119409438138438, 'trim_C300'),
#  (0.0011927811997009563, 'model_X3'),
#  (0.0011915395735108644, 'model_Durango'),
#  (0.0011874597404321694, 'model_Sienna'),
#  (0.001171528875543822, 'model_Silverado 2500HD'),
#  (0.0011683109807895142, 'model_Sonoma'),
#  (0.0011406666395994362, 'trim_SR5'),
#  (0.0011401097003427931, 'trim_1LS'),
#  (0.0011362071812425283, 'model_M5'),
#  (0.0011356689554013807, 'model_Cooper'),
#  (0.0011207663511974511, 'model_HR-V'),
#  (0.0011112856504694583, 'trim_GLE350'),
#  (0.0011008128514267167, 'model_Commander'),
#  (0.0010983610511702193, 'model_Armada'),
#  (0.0010958985732538596, 'model_Tundra'),
#  (0.0010923041784126535, 'model_Impreza'),
#  (0.001057224178888379, 'model_Altima Sedan'),
#  (0.0010535666019070241, 'model_Flex'),
#  (0.001050706656514276, 'trim_HSE'),
#  (0.001025145760454086, 'model_Versa Note'),
#  (0.0010214454435711953, 'trim_40i'),
#  (0.0010166208368863965, 'model_MAZDA3'),
#  (0.001014195455690466, 'trim_Work Truck'),
#  (0.0010098860951089463, 'trim_Jetta'),
#  (0.0010098196741205382, 'model_Pathfinder'),
#  (0.0010064003510116561, 'trim_SLE-2'),
#  (0.0009926323111774686, 'trim_M340i'),
#  (0.0009706786652907235, 'model_Passat'),
#  (0.0009553040094947654, 'model_Crown Victoria'),
#  (0.000950159728315014, 'trim_AT4'),
#  (0.0009360918596400626, 'trim_CX'),
#  (0.0009230600451379227, 'model_Navigator'),
#  (0.0009101704695715729, 'model_Sorento'),
#  (0.0009081881292176558, 'trim_LIMITED'),
#  (0.0009010848456690762, 'model_Forester'),
#  (0.000896027978031235, 'model_Range Rover Velar'),
#  (0.000890713393670537, 'trim_Rubicon'),
#  (0.0008859089276223138, 'trim_Custom'),
#  (0.0008819340076129943, 'model_Outback'),
#  (0.0008780088755103214, 'trim_Titanium'),
#  (0.0008661859081103529, 'model_Avenger'),
#  (0.0008657035449861445, 'trim_3LT'),
#  (0.0008587607960572226, 'model_M4 Coupe'),
#  (0.0008545393196414491, 'model_FORTE'),
#  (0.0008521921796400059, 'model_Spark'),
#  (0.0008449168433669242, 'trim_SLS'),
#  (0.0008313414042495252, 'model_Sportage'),
#  (0.0008180384097192778, 'model_S-Class'),
#  (0.0008179910708654112, 'model_Escalade ESV'),
#  (0.0008073007615211584, 'model_Prius c'),
#  (0.0008035045797787619, 'trim_Altitude'),
#  (0.000798058120481749, 'model_GLS-Class'),
#  (0.0007959295468522098, 'model_Tacoma'),
#  (0.0007903300855231836, 'model_Versa Sedan'),
#  (0.0007873078617617406, 'model_Legacy'),
#  (0.0007853136379610981, 'model_Sierra 2500 Denali HD'),
#  (0.0007781478506842809, 'model_GLC-Class'),
#  (0.0007747347055552026, 'model_Panamera'),
#  (0.0007737625829703551, 'make_Isuzu'),
#  (0.0007673820845048797, 'trim_L200'),
#  (0.0007613164469527908, 'trim_Black Label'),
#  (0.0007472749000317228, 'model_Sonic'),
#  (0.0007449272216311705, 'trim_Latitude'),
#  (0.0007329416167300364, 'model_GLC Coupe'),
#  (0.0007296660263397131, 'model_Titan'),
#  (0.0007282856342628989, 'trim_ES'),
#  (0.0007243464450409918, 'model_CLS-Class'),
#  (0.0007176811351102917, 'model_300'),
#  (0.0007138692322872527, 'model_Crosstrek'),
#  (0.0007131522275644294, 'make_Saturn'),
#  (0.0007105323445049079, 'model_Ascender'),
#  (0.0007044316999084269, 'model_Yaris'),
#  (0.0007040169900676283, 'trim_Mojave'),
#  (0.0007009831432021617, 'trim_Sahara'),
#  (0.0006980400163594118, 'trim_525i'),
#  (0.0006946326198791438, 'trim_Express'),
#  (0.0006934069228992077, 'model_Ridgeline'),
#  (0.000690422260079947, 'model_F-TYPE'),
#  (0.0006903732413395448, 'model_X6 M'),
#  (0.0006884283697542828, 'model_Town & Country'),
#  (0.0006877728411241574, 'model_Prius v'),
#  (0.0006788766422552023, 'trim_2LT'),
#  (0.000676084800967544, 'trim_HSE Dynamic'),
#  (0.000674921426021778, 'model_LS'),
#  (0.0006740952900241529, 'model_Renegade'),
#  (0.0006655242293156452, 'model_Optima'),
#  (0.0006616452927672886, 'trim_SRT'),
#  (0.000649272953477356, 'make_MINI'),
#  (0.0006454183307827256, 'make_Jaguar'),
#  (0.000638889908532861, 'model_Frontier'),
#  (0.0006309179019676006, 'model_V90 Cross Country'),
#  (0.0006214026218086747, 'model_Elantra GT'),
#  (0.0006196997738369059, 'trim_R/T'),
#  (0.0006137686920907706, 'model_QX60'),
#  (0.0006110935132539353, 'model_Escalade'),
#  (0.0006051101590772836, 'trim_3.0 EX'),
#  (0.0006042818714880749, 'model_Range Rover'),
#  (0.0006031897749441353, 'trim_SR5 Premium'),
#  (0.0006011161060394718, 'model_TrailBlazer'),
#  (0.0005926131448535981, 'model_Maxima'),
#  (0.0005894983601952293, 'trim_28i'),
#  (0.0005893249475212527, 'model_E-Class'),
#  (0.0005791626939404643, 'model_TSX'),
#  (0.0005784472252792629, 'model_G6'),
#  (0.0005735563983361876, 'model_M'),
#  (0.0005726350158316498, 'trim_High Altitude'),
#  (0.0005656093586942777, 'model_Ram 3500 Pickup'),
#  (0.0005610046187360298, 'trim_xDrive35d'),
#  (0.0005602473506313298, 'model_CC'),
#  (0.0005561833414422885, 'trim_LE Plus'),
#  (0.0005495005698879625, 'trim_Grand Touring'),
#  (0.0005488488036503101, 'model_Silverado'),
#  (0.0005487998513280732, 'trim_SL450'),
#  (0.0005453839901333053, 'trim_EX-L V-6'),
#  (0.0005435577593013048, 'model_QX80'),
#  (0.000541575057953228, 'model_Fit'),
#  (0.0005396983979440928, 'model_Camaro'),
#  (0.0005374436868131867, 'trim_Z71'),
#  (0.0005371576434586935, 'trim_Overland'),
#  (0.0005371381852863821, 'trim_High Country'),
#  (0.000532442218683798, 'trim_Sport Touring'),
#  (0.0005308628407726445, 'trim_PRO-4X'),
#  (0.0005275954733750983, 'model_Outlander'),
#  (0.0005253602150480373, 'trim_Laredo'),
#  (0.0005246373845201513, 'trim_SVR'),
#  (0.0005228853177560564, 'model_Impala'),
#  (0.0005149970915176091, 'trim_750i'),
#  (0.0005132274973234456, 'model_MDX'),
#  (0.0005129499997469554, 'model_Cherokee'),
#  (0.0005096812786974381, 'trim_2.5T'),
#  (0.0005054175097871229, 'model_8 Series'),
#  (0.0005032984206958156, 'model_IS'),
#  (0.0004996282825316841, 'trim_CLA250'),
#  (0.0004980964074521535, 'trim_330i'),
#  (0.0004913013930012044, 'trim_200t'),
#  (0.0004903246097599025, 'trim_Power Wagon'),
#  (0.00048578875961019947, 'trim_X'),
#  (0.0004801714713128184, 'model_Accent'),
#  (0.00047517734111991754, 'model_Q7'),
#  (0.0004742084850438578, 'model_Element'),
#  (0.00047245945589625277, 'model_MAZDA6'),
#  (0.0004658455005472463, 'model_Dart'),
#  (0.0004618792092082396, 'model_Transit Passenger Van'),
#  (0.00046156807726872813, 'trim_LUXE'),
#  (0.00046112798370271247, 'trim_RST'),
#  (0.0004607376845559486, 'trim_Touring Elite'),
#  (0.00045578071979581624, 'make_Suzuki'),
#  (0.0004519645347578695, 'model_GLB'),
#  (0.00045138165029038805, 'model_Grand Prix'),
#  (0.00044714698114366327, 'model_G35'),
#  (0.0004414182427918739, 'trim_EX-P'),
#  (0.00044039893552085403, 'model_4Runner'),
#  (0.00043761010888540683, 'model_Cruze Limited'),
#  (0.00043617026155800333, 'model_Sierra 1500 Denali'),
#  (0.00043312191137938376, 'model_Freestar'),
#  (0.0004311501494350306, 'model_Crosstour'),
#  (0.00042947875716014357, 'trim_3.0si'),
#  (0.0004274657066025867, 'model_RX'),
#  (0.00042722530337083045, 'model_M2 Coupe'),
#  (0.00042648106494009365, 'model_Yukon'),
#  (0.0004240152971863633, 'model_Murano'),
#  (0.0004190553808829406, 'trim_xDrive30i'),
#  (0.0004177885628755337, 'model_MKS'),
#  (0.0004161271739146588, 'trim_SXT Plus'),
#  (0.0004152255105633203, 'model_Tiguan'),
#  (0.00040827544903289506, 'model_i8'),
#  (0.00040638825477468414, 'trim_+'),
#  (0.00040340338174927324, 'model_TL'),
#  (0.00039300128023997497, 'model_Golf GTI'),
#  (0.00039030677052231906, 'model_Avalanche'),
#  (0.0003854150927346196, 'trim_Hybrid SE'),
#  (0.0003835571483815553, 'trim_FX4'),
#  (0.00038046582219225305, 'model_Revero'),
#  (0.0003770151441133367, 'model_LR4'),
#  (0.000374372407771229, 'model_S2000'),
#  (0.00037387176320234113, 'model_CX-9'),
#  (0.00037315373498805467, 'trim_Luxury Collection'),
#  (0.0003685455737597548, 'model_AMG GT'),
#  (0.0003671953481501346, 'model_Yukon XL'),
#  (0.000364032631676394, 'model_X7'),
#  (0.0003638038738221133, 'trim_Rubicon Recon'),
#  (0.00036277348213206636, 'model_Routan'),
#  (0.0003602728177338477, 'make_Scion'),
#  (0.00035996680389767036, 'trim_E350 Luxury'),
#  (0.00035996247698272173, 'trim_Premier'),
#  (0.00035931964917284843, 'model_Avalon'),
#  (0.0003580873642717086, 'model_Trax'),
#  (0.0003567777670242951, 'trim_GLS550'),
#  (0.0003548501569537551, 'model_Encore'),
#  (0.0003547422277530081, 'trim_SX'),
#  (0.0003499413773608451, 'model_XC60'),
#  (0.0003489821909820933, 'trim_Platinum Reserve'),
#  (0.000347797725957661, 'trim_50i'),
#  (0.00034700122399020756, 'trim_CXL-1'),
#  (0.0003436856123423288, 'trim_XLS'),
#  (0.00034291569623900173, 'model_Pacifica'),
#  (0.0003400540580027754, 'trim_Autobahn'),
#  (0.00033846892120891685, 'model_Atlas'),
#  (0.00033689637990813137, 'trim_SI'),
#  (0.00033639599774015256, 'model_Enclave'),
#  (0.0003346691511337862, 'model_Macan'),
#  (0.00033313114252982515, 'model_Veloster'),
#  (0.00032580490612510167, 'trim_Trekking'),
#  (0.0003256296080558548, 'model_L-Series'),
#  (0.00032467951259011426, 'trim_xDrive28i'),
#  (0.0003246625825199746, 'model_C-Class'),
#  (0.0003239686178396037, 'trim_Value Edition'),
#  (0.0003236496309876303, 'model_NX'),
#  (0.00032276981632581346, 'model_Sierra 3500'),
#  (0.0003182541720154027, 'model_MKZ'),
#  (0.00031671151290340785, 'trim_Technology & Entertainment Package'),
#  (0.00031649732339909364, 'trim_SLT-1'),
#  (0.0003157047382040211, 'model_Regal'),
#  (0.00031500269651021115, 'model_All-New Wrangler Unlimited'),
#  (0.00031462582997602797, 'trim_2.5'),
#  (0.00030933367160353544, 'model_Canyon'),
#  (0.00030885131485387915, 'model_2 Series'),
#  (0.00030760508439192245, 'model_CLA-Class'),
#  (0.0003056938097686707, 'model_Sierra 3500 Denali HD'),
#  (0.00030518186347782745, 'trim_RTL'),
#  (0.0003051410040917504, 'model_S7'),
#  (0.0003039698772976664, 'model_Mazda3'),
#  (0.0003038338956695957, 'model_Wrangler'),
#  (0.00029552868931107294, 'trim_Commercial'),
#  (0.0002938135337780867, 'trim_CUSTOM'),
#  (0.00029154165079163535, 'model_Wrangler JK Unlimited'),
#  (0.000288363657506378, 'model_SL Roadster'),
#  (0.0002862662756625409, 'trim_Performance Collection'),
#  (0.00028437452426803046, 'trim_840i'),
#  (0.00028178593654691055, 'trim_XSE'),
#  (0.00027946695398043894, 'trim_Z51'),
#  (0.0002779194902260989, 'model_Azera'),
#  (0.00027753261739467676, 'model_Kona'),
#  (0.0002773283449996236, 'model_Cayenne'),
#  (0.000275247143197464, 'model_Giulia'),
#  (0.0002743350246306971, 'model_Lucerne'),
#  (0.00027396946469325853, 'model_Jetta SportWagen'),
#  (0.00027357650374306466, 'model_Transit Van'),
#  (0.00027222296201320946, 'model_Venza'),
#  (0.0002719745702218124, 'model_Savana Cargo'),
#  (0.00027047096335172335, 'model_Touareg'),
#  (0.0002704194260485652, 'model_Yaris iA'),
#  (0.0002651230251305288, 'model_GLE'),
#  (0.00026230983004952457, 'trim_American Value Package'),
#  (0.0002586826846002674, 'model_Suburban'),
#  (0.0002569209717568917, 'trim_AMG® C43'),
#  (0.0002552199936035087, 'model_Prius Plug-In'),
#  (0.000254082073058089, 'model_Ram 1500 Classic'),
#  (0.0002518449871196653, 'model_Kicks'),
#  (0.0002509739028510359, 'model_SSR'),
#  (0.00024893999609124274, 'trim_2.0I Premium'),
#  (0.0002477558017006653, 'model_Fusion Hybrid'),
#  (0.0002457460205575718, 'trim_2SS'),
#  (0.0002450769100743745, 'make_Saab'),
#  (0.0002450157515751585, 'model_CT'),
#  (0.00024432137269756306, 'trim_M3'),
#  (0.00024267203536399383, 'trim_30i'),
#  (0.00024093223543783442, 'trim_FE'),
#  (0.00024031642051543022, 'model_RDX'),
#  (0.00024025496445207156, 'model_Land Cruiser'),
#  (0.00024015310334105303, 'model_Q8'),
#  (0.00023992794333704937, 'model_Sierra 2500HD'),
#  (0.00023867263607345695, 'trim_400'),
#  (0.00023502342587829672, 'trim_Trailhawk'),
#  (0.0002345162653147437, 'model_Golf Alltrack'),
#  (0.00023006625055918962, 'model_G80'),
#  (0.00022712856794340086, 'model_A6'),
#  (0.00022443075084420776, 'trim_Touring L'),
#  (0.00022361586060902123, 'trim_Z71 LTZ'),
#  (0.00022143589748102076, 'model_4 Series'),
#  (0.00022045953867593694, 'model_M Series'),
#  (0.0002173578835674321, 'trim_SLT1'),
#  (0.00021546156594388105, 'trim_XE'),
#  (0.00021418452820891776, 'trim_XLE Premium'),
#  (0.00021376084566739647, 'model_Volt'),
#  (0.00021344708729867086, 'model_G70'),
#  (0.0002132183908045976, 'model_Phantom'),
#  (0.00021186317462779165, 'trim_Three'),
#  (0.00021169898954844605, 'trim_Sensory 4WD'),
#  (0.0002109444177217611, 'trim_570'),
#  (0.00021015905896386612, 'model_GLE-Class'),
#  (0.00020971484556283324, 'model_S80'),
#  (0.0002097024216693469, 'trim_Premium 2'),
#  (0.00020950095334116138, 'trim_GLC300'),
#  (0.00020695188935212662, 'trim_GLA250'),
#  (0.00020632563466310456, 'trim_TDI SE'),
#  (0.00020021247037672635, 'trim_SES'),
#  (0.0001999720198524393, 'trim_Hybrid Limited'),
#  (0.00019785136678240935, 'trim_Club'),
#  (0.00019755960995000675, 'trim_S560'),
#  (0.00019630847219433817, 'trim_Ocean Race'),
#  (0.00019618127147597752, 'trim_Tundra Grade'),
#  (0.00019483360405306245, 'trim_s Grand Touring'),
#  (0.00019405940594059405, 'trim_LX-S'),
#  (0.00019329065749639624, 'trim_Two'),
#  (0.0001895951424022041, 'trim_250'),
#  (0.0001893805767257784, 'model_Camry Solara'),
#  (0.00018733225795164202, 'model_XT6'),
#  (0.00018631178707224336, 'model_Palisade'),
#  (0.00018242740134028293, 'trim_AMG® GLE43'),
#  (0.00018242740134028293, 'make_KARMA'),
#  (0.0001811953520520767, 'trim_GL450'),
#  (0.00018085629921259846, 'trim_Energi SEL'),
#  (0.00017988252569750367, 'trim_Willys'),
#  (0.0001797548045062956, 'model_GLC'),
#  (0.00017926829268292684, 'trim_STX'),
#  (0.00017849431058783962, 'trim_S Plus'),
#  (0.00017660697103483232, 'model_Xterra'),
#  (0.00017467890338218007, 'model_Silverado 3500HD'),
#  (0.00016951855182545882, 'model_6 Series'),
#  (0.00016793145654834765, 'trim_Eco'),
#  (0.00016755412479241296, 'trim_Carrera 4S'),
#  (0.0001663294667745707, 'trim_TRD Pro'),
#  (0.00016556799336650094, 'model_Passport'),
#  (0.00016555989012594617, 'trim_Carrera'),
#  (0.00016507000736919682, 'trim_R-Line'),
#  (0.0001639278103607595, 'trim_LT2'),
#  (0.00016389030428931643, 'trim_Advanced'),
#  (0.00016237824238496463, 'model_CX-5'),
#  (0.00016204080695598062, 'model_Golf SportWagen'),
#  (0.00016155621496867793, 'trim_330e'),
#  (0.00016060308095706326, 'trim_3.8'),
#  (0.0001602485487695201, 'model_MKX'),
#  (0.00016005226196308997, 'trim_Wolfsburg Edition'),
#  (0.00015989557839778107, 'model_Clubman'),
#  (0.00015989557839778102, 'model_Rogue Sport'),
#  (0.0001596221190650704, 'trim_Laramie Longhorn'),
#  (0.0001595937070833003, 'model_LaCrosse'),
#  (0.0001594662761370108, 'model_Savana'),
#  (0.00015756124169657347, 'trim_Rebel'),
#  (0.0001574748923959827, 'trim_37x'),
#  (0.00015696347031963456, 'trim_V6'),
#  (0.00015400206533382088, 'trim_330'),
#  (0.00015382675238534774, 'trim_R-Sport'),
#  (0.00015308943089430862, 'trim_37 Journey'),
#  (0.00015276522682089273, 'trim_TRD'),
#  (0.00015107687329210377, 'model_A5'),
#  (0.0001498593703066548, 'trim_Laredo X'),
#  (0.00014965907777649316, 'trim_Longhorn'),
#  (0.00014951344219033493, 'model_GLS'),
#  (0.00014685314685314684, 'model_XC90'),
#  (0.00014516794785580705, 'trim_E300'),
#  (0.0001449382109828956, 'trim_Select'),
#  (0.0001435546875, 'trim_SE Nightshade'),
#  (0.00014251974916524145, 'model_XC70'),
#  (0.0001401148309516823, 'model_Ecosport'),
#  (0.00013834049053232242, 'trim_Night'),
#  (0.00013816925734024172, 'trim_Momentum'),
#  (0.00013801454069652723, 'trim_Inscription'),
#  (0.0001374233128834355, 'model_F-450 Super Duty'),
#  (0.00013518141517152168, 'trim_i Sport'),
#  (0.0001348205986242798, 'model_Boxster'),
#  (0.00013447842852670842, 'trim_C300 Luxury'),
#  (0.00013438539699667292, 'trim_SLE-1'),
#  (0.00013435259543031287, 'make_Maserati'),
#  (0.0001315797447259784, 'model_Silverado 1500 LD'),
#  (0.00013141762452107287, 'trim_SL550'),
#  (0.0001296315231663396, 'trim_Two Eco'),
#  (0.0001287953279103721, 'trim_Hybrid Touring'),
#  (0.00012732676630434762, 'make_Alfa Romeo'),
#  (0.00012665477065057775, 'model_S60'),
#  (0.0001263057929724597, 'trim_Citadel'),
#  (0.00012496221852803383, 'model_GLE-Class Coupe'),
#  (0.00012489912563208445, 'model_S-10'),
#  (0.0001248568370852969, 'trim_E320'),
#  (0.0001244896664837728, 'model_STS'),
#  (0.0001242314453202673, 'model_XT5'),
#  (0.00012422782150308374, 'trim_Technology & A-SPEC Packages'),
#  (0.0001241034816968615, 'trim_S500'),
#  (0.00012400932400932408, 'trim_ZL1'),
#  (0.00012394878736104033, 'trim_Tradesman'),
#  (0.00012388145816942024, 'model_Discovery Sport'),
#  (0.00012334543013572198, 'model_TLX'),
#  (0.00012201195219123503, 'model_Countryman'),
#  (0.0001216182675601886, 'trim_SXT 30th Anniversary'),
#  (0.00012154379530672473, 'model_NV Cargo'),
#  (0.00012122711528946066, 'trim_Black Label Grand Touring'),
#  (0.00012119713084343308, 'trim_428i'),
#  (0.00012119713084343308, 'trim_2.0I Limited'),
#  (0.0001210431022324522, 'trim_TDI S'),
#  (0.00012071938901207191, 'trim_RS'),
#  (0.00012063023141309701, 'model_C-Class Sedan'),
#  (0.00012044563583335845, 'trim_Lusso'),
#  (0.00012024539877300614, 'model_MINI'),
#  (0.00012012748222603578, 'trim_328d'),
#  (0.00011986301369863011, 'trim_EcoBoost'),
#  (0.00011986301369863011, 'model_E-PACE'),
#  (0.00011968734733756716, 'trim_Value'),
#  (0.00011965811965811966, 'model_JX'),
#  (0.00011907654921020654, 'model_GX'),
#  (0.00011891914678357643, 'trim_2.4i'),
#  (0.00011796735479442858, 'model_X1'),
#  (0.00011636587826476868, 'model_SRX'),
#  (0.00011612812875356128, 'trim_LXS'),
#  (0.00011539547340813793, 'model_G Sedan'),
#  (0.00011537750165986875, 'trim_Upland'),
#  (0.00011481711489474245, 'trim_T6'),
#  (0.00011426914900470312, 'trim_Preferred'),
#  (0.00011410478029943446, 'trim_F'),
#  (0.00011223439637536546, 'model_allroad'),
#  (0.00011130871931619013, 'trim_Release Series 8.0'),
#  (0.00011097664468893981, 'model_Forte5'),
#  (0.00011072830999481373, 'model_C-Class Coupe'),
#  (0.0001099464911698195, 'trim_Essence'),
#  (0.00010887748498613514, 'model_Continental'),
#  (0.00010636157907970736, 'trim_Work Van'),
#  (0.00010565997663799494, 'trim_Elite'),
#  (0.0001048904643864773, 'trim_SLK350'),
#  (0.00010469959727459814, 'model_Liberty'),
#  (0.0001037977599262907, 'trim_2.5i Premium'),
#  (0.0001036104414473097, 'trim_Essential'),
#  (0.00010351924544760665, 'model_Fusion Energi'),
#  (0.0001033411033411033, 'model_CX-3'),
#  (0.00010258915486077185, 'trim_Rubicon Hard Rock'),
#  (0.00010072738772928498, 'trim_530e'),
#  (0.00010062447746933064, 'model_MKC'),
#  (0.00010015534298095014, 'model_Insight'),
#  (9.84395290062497e-05, 'trim_xDrive35i'),
#  (9.830104695630376e-05, 'trim_Deluxe'),
#  (9.732794231021706e-05, 'trim_i Grand Touring'),
#  (9.334095300296632e-05, 'trim_AMG® GLE63 S'),
#  (9.12498983491907e-05, 'trim_Laredo E'),
#  (9.049449721091521e-05, 'model_Sedona'),
#  (8.933416049724963e-05, 'trim_Daytona'),
#  (8.400685770266961e-05, 'trim_xDrive50i'),
#  (8.269204806264345e-05, 'trim_E350 Sport'),
#  (8.139534883720922e-05, 'make_FIAT'),
#  (8.117958913187554e-05, 'trim_II'),
#  (8.108159428820965e-05, 'trim_EX-L V6'),
#  (8.00457404230989e-05, 'trim_Base/Premiere'),
#  (8.000653114539963e-05, 'trim_Touring L Plus'),
#  (7.832247896035932e-05, 'model_Silverado Classic 3500'),
#  (7.725563862881717e-05, 'trim_Mega World'),
#  (7.56300679377603e-05, 'model_XTS'),
#  (7.473105034080638e-05, 'trim_GLS580'),
#  (7.452907452907447e-05, 'model_C-HR'),
#  (7.081504103836606e-05, 'model_Promaster City'),
#  (6.669111654441748e-05, 'model_7 Series'),
#  (6.574774335203717e-05, 'trim_VR6'),
#  (6.01965601965602e-05, 'model_X2'),
#  (5.757052389176721e-05, 'trim_CXL'),
#  (5.662485073381197e-05, 'model_Eclipse Cross'),
#  (5.627009646302252e-05, 'trim_C300 Sport'),
#  (5.352120368094802e-05, 'trim_ML350'),
#  (5.3207373021690163e-05, 'model_X6'),
#  (4.840701407755007e-05, 'trim_Standard'),
#  (4.8145418816015716e-05, 'model_Envision'),
#  (4.271876009041022e-05, 'model_Ascent'),
#  (4.13162624536801e-05, 'model_Hardtop 2 Door'),
#  (4.0559556328118524e-05, 'trim_CLS53'),
#  (3.295232210894866e-05, 'trim_Latitude Plus'),
#  (3.2431538016050265e-05, 'trim_EX Hybrid'),
#  (3.1893255227402155e-05, 'model_S90'),
#  (2.6661029406517803e-05, 'trim_2.5i'),
#  (2.3016851623510096e-05, 'model_CT5'),
#  (2.0269711260031444e-05, 'trim_645CiC'),
#  (2.0070451380355462e-05, 'model_Regal Sportback'),
#  (1.2765830746670876e-05, 'model_VUE'),
#  (1.2149764443342381e-05, 'trim_SLT Standard Edition'),
#  (2.663622526636296e-06, 'trim_TDI'),
#  (0.0, 'trim_xDrive40e'),
#  (0.0, 'trim_xDrive28d'),
#  (0.0, 'trim_sDrive35i'),
#  (0.0, 'trim_sDrive28i'),
#  (0.0, 'trim_i Premium'),
#  (0.0, 'trim_ZR2'),
#  (0.0, 'trim_Z06'),
#  (0.0, 'trim_XR'),
#  (0.0, 'trim_XLE Touring Sport Edition'),
#  (0.0, 'trim_XLE Touring'),
#  (0.0, 'trim_XLE Hybrid'),
#  (0.0, 'trim_Work Truck 1WT'),
#  (0.0, 'trim_Work'),
#  (0.0, 'trim_Winter'),
#  (0.0, 'trim_Willys Wheeler'),
#  (0.0, 'trim_Warlock'),
#  (0.0, 'trim_WRX Premium'),
#  (0.0, 'trim_V6 Premium'),
#  (0.0, 'trim_V-Series'),
#  (0.0, 'trim_V'),
#  (0.0, 'trim_Ultimate'),
#  (0.0, 'trim_Type-R'),
#  (0.0, 'trim_Touring-L Plus'),
#  (0.0, 'trim_Touring-L'),
#  (0.0, 'trim_Touring Plus'),
#  (0.0, 'trim_Ti Sport'),
#  (0.0, 'trim_Ti'),
#  (0.0, 'trim_Technology Plus'),
#  (0.0, 'trim_Technology & A-Spec Package'),
#  (0.0, 'trim_Targa 4S'),
#  (0.0, 'trim_TSI S'),
#  (0.0, 'trim_TSI Limited Edition'),
#  (0.0, 'trim_TRD Sport'),
#  (0.0, 'trim_TRD Off Road'),
#  (0.0, 'trim_T6 Dynamic'),
#  (0.0, 'trim_T5 Inscription'),
#  (0.0, 'trim_T5'),
#  (0.0, 'trim_Supercharged'),
#  (0.0, 'trim_Summit'),
#  (0.0, 'trim_Stinger'),
#  (0.0, 'trim_Sport SE'),
#  (0.0, 'trim_Sport 2.0T'),
#  (0.0, 'trim_Signature'),
#  (0.0, 'trim_Si'),
#  (0.0, 'trim_Scat Pack'),
#  (0.0, 'trim_SX Limited'),
#  (0.0, 'trim_SRT8'),
#  (0.0, 'trim_SPORT'),
#  (0.0, 'trim_SLT2'),
#  (0.0, 'trim_SLT-2'),
#  (0.0, 'trim_SLE2'),
#  (0.0, 'trim_SLE1'),
#  (0.0, 'trim_SEL R-Line'),
#  (0.0, 'trim_SEL Premium'),
#  (0.0, 'trim_SEL Plus'),
#  (0.0, 'trim_SE1'),
#  (0.0, 'trim_SE w/Tech R-Line'),
#  (0.0, 'trim_SE w/Tech'),
#  (0.0, 'trim_SE R-Line w/Tech'),
#  (0.0, 'trim_SE Plus'),
#  (0.0, 'trim_SE Luxury'),
#  (0.0, 'trim_S63 AMG®'),
#  (0.0, 'trim_S550'),
#  (0.0, 'trim_S55 AMG'),
#  (0.0, 'trim_S450'),
#  (0.0, 'trim_S line Prestige'),
#  (0.0, 'trim_S Line Prestige'),
#  (0.0, 'trim_S Line Premium Plus'),
#  (0.0, 'trim_S Line Premium'),
#  (0.0, 'trim_S Krom Edition'),
#  (0.0, 'trim_S E PHEV'),
#  (0.0, 'trim_Rubicon X'),
#  (0.0, 'trim_RTL-T'),
#  (0.0, 'trim_RTL-E'),
#  (0.0, 'trim_RF'),
#  (0.0, 'trim_RED SPORT'),
#  (0.0, 'trim_R350'),
#  (0.0, 'trim_R/T Plus'),
#  (0.0, 'trim_R/T Classic'),
#  (0.0, 'trim_R-Design'),
#  (0.0, 'trim_R'),
#  (0.0, 'trim_QUATTRO'),
#  (0.0, 'trim_Pure Plus'),
#  (0.0, 'trim_Pure'),
#  (0.0, 'trim_Pro-4X'),
#  (0.0, 'trim_Premium II'),
#  (0.0, 'trim_Preferred II'),
#  (0.0, 'trim_Preferred AWD'),
#  (0.0, 'trim_PreRunner'),
#  (0.0, 'trim_Plus'),
#  (0.0, 'trim_Platinum Edition'),
#  (0.0, 'trim_Persona Series'),
#  (0.0, 'trim_Performante'),
#  (0.0, 'trim_PURE'),
#  (0.0, 'trim_PREMIUM'),
#  (0.0, 'trim_One'),
#  (0.0, 'trim_Off-Road Premium'),
#  (0.0, 'trim_Off-Road'),
#  (0.0, 'trim_North Edition'),
#  (0.0, 'trim_Nismo'),
#  (0.0, 'trim_NISMO'),
#  (0.0, 'trim_Mazdaspeed3 Touring'),
#  (0.0, 'trim_Mainstreet'),
#  (0.0, 'trim_M6'),
#  (0.0, 'trim_M50i'),
#  (0.0, 'trim_M440i'),
#  (0.0, 'trim_M40i'),
#  (0.0, 'trim_M240i'),
#  (0.0, 'trim_M235i'),
#  (0.0, 'trim_Lone Star Silver'),
#  (0.0, 'trim_Lone Star'),
#  (0.0, 'trim_Limited Ultimate'),
#  (0.0, 'trim_Limited Sterling Edition'),
#  (0.0, 'trim_Limited Platinum'),
#  (0.0, 'trim_Limited Hybrid'),
#  (0.0, 'trim_Leather'),
#  (0.0, 'trim_LX-P'),
#  (0.0, 'trim_LUXURY'),
#  (0.0, 'trim_LT Z71'),
#  (0.0, 'trim_LT Trail Boss'),
#  (0.0, 'trim_LE Eco'),
#  (0.0, 'trim_John Cooper Works'),
#  (0.0, 'trim_Inscription Platinum'),
#  (0.0, 'trim_IV'),
#  (0.0, 'trim_I Premium'),
#  (0.0, 'trim_Hybrid EX'),
#  (0.0, 'trim_Hybrid'),
#  (0.0, 'trim_High Altitude Edition'),
#  (0.0, 'trim_HSE LUX'),
#  (0.0, 'trim_HEV'),
#  (0.0, 'trim_Grand Touring Reserve'),
#  (0.0, 'trim_Grand Touring Hard Top'),
#  (0.0, 'trim_Grand Sport'),
#  (0.0, 'trim_Grand Select'),
#  (0.0, 'trim_GT2'),
#  (0.0, 'trim_GT-Line'),
#  (0.0, 'trim_GT Premium'),
#  (0.0, 'trim_GT Plus'),
#  (0.0, 'trim_GLI Autobahn'),
#  (0.0, 'trim_GLI'),
#  (0.0, 'trim_GLB250'),
#  (0.0, 'trim_GL'),
#  (0.0, 'trim_Four'),
#  (0.0, 'trim_Fleet'),
#  (0.0, 'trim_Five'),
#  (0.0, 'trim_F Sport'),
#  (0.0, 'trim_Exclaim'),
#  (0.0, 'trim_Edition One'),
#  (0.0, 'trim_Eddie Bauer'),
#  (0.0, 'trim_EcoBoost Premium'),
#  (0.0, 'trim_EX-T'),
#  (0.0, 'trim_E550 Sport'),
#  (0.0, 'trim_E400'),
#  (0.0, 'trim_E350'),
#  (0.0, 'trim_Dynamic'),
#  (0.0, 'trim_DE'),
#  (0.0, 'trim_Crossroad'),
#  (0.0, 'trim_CrossRoad'),
#  (0.0, 'trim_Crafted Line'),
#  (0.0, 'trim_Countryman S'),
#  (0.0, 'trim_Convenience'),
#  (0.0, 'trim_Classica'),
#  (0.0, 'trim_Carbonite Edition'),
#  (0.0, 'trim_Carbon Edition'),
#  (0.0, 'trim_CLS550'),
#  (0.0, 'trim_C250 Sport'),
#  (0.0, 'trim_C250 Luxury'),
#  (0.0, 'trim_C'),
#  (0.0, 'trim_Blue'),
#  (0.0, 'trim_Black Edition'),
#  (0.0, 'trim_Big Bend'),
#  (0.0, 'trim_Avenir'),
#  (0.0, 'trim_Alltrack SEL'),
#  (0.0, 'trim_Alltrack S'),
#  (0.0, 'trim_Aero'),
#  (0.0, 'trim_Adventure'),
#  (0.0, 'trim_Advance Package'),
#  (0.0, 'trim_AcuraWatch Plus Package'),
#  (0.0, 'trim_AWD'),
#  (0.0, 'trim_AMG® GLC63'),
#  (0.0, 'trim_AMG® E53'),
#  (0.0, 'trim_AMG® E43'),
#  (0.0, 'trim_AMG® C63'),
#  (0.0, 'trim_AMG GLC43'),
#  (0.0, 'trim_AMG CLS63'),
#  (0.0, 'trim_ALPINA B7'),
#  (0.0, 'trim_A-Spec Package'),
#  (0.0, 'trim_75th Anniversary Edition'),
#  (0.0, 'trim_75th Anniversary'),
#  (0.0, 'trim_740i'),
#  (0.0, 'trim_740Li'),
#  (0.0, 'trim_650i'),
#  (0.0, 'trim_56'),
#  (0.0, 'trim_540i'),
#  (0.0, 'trim_535xi'),
#  (0.0, 'trim_535i'),
#  (0.0, 'trim_528i'),
#  (0.0, 'trim_50th Anniversary Special Edition'),
#  (0.0, 'trim_500 F SPORT'),
#  (0.0, 'trim_470'),
#  (0.0, 'trim_450hL LUXURY'),
#  (0.0, 'trim_440i'),
#  (0.0, 'trim_430i'),
#  (0.0, 'trim_4.8is'),
#  (0.0, 'trim_3SA'),
#  (0.0, 'trim_37'),
#  (0.0, 'trim_35i'),
#  (0.0, 'trim_350 Ultra Luxury'),
#  (0.0, 'trim_350 F Sport'),
#  (0.0, 'trim_350 F SPORT'),
#  (0.0, 'trim_35 Journey'),
#  (0.0, 'trim_340i'),
#  (0.0, 'trim_335i'),
#  (0.0, 'trim_325'),
#  (0.0, 'trim_320i'),
#  (0.0, 'trim_300h'),
#  (0.0, 'trim_300 F SPORT'),
#  (0.0, 'trim_300'),
#  (0.0, 'trim_3.2'),
#  (0.0, 'trim_2SA'),
#  (0.0, 'trim_2LZ'),
#  (0.0, 'trim_2FL'),
#  (0.0, 'trim_228i'),
#  (0.0, 'trim_200 F SPORT'),
#  (0.0, 'trim_200'),
#  (0.0, 'trim_2.0T'),
#  (0.0, 'trim_2.0I Sport Limited'),
#  (0.0, 'trim_2.0 S'),
#  (0.0, 'trim_1SS'),
#  (0.0, 'trim_1SL'),
#  (0.0, 'model_tC'),
#  (0.0, 'model_iA'),
#  (0.0, 'model_i3'),
#  (0.0, 'model_XV Crosstrek'),
#  (0.0, 'model_XT4'),
#  (0.0, 'model_XJ'),
#  (0.0, 'model_XF'),
#  (0.0, 'model_XE'),
#  (0.0, 'model_XC40'),
#  (0.0, 'model_X4'),
#  (0.0, 'model_X2 M'),
#  (0.0, 'model_WRX STI'),
#  (0.0, 'model_WRX'),
#  (0.0, 'model_Versa'),
#  (0.0, 'model_Verano'),
#  (0.0, 'model_Veracruz'),
#  (0.0, 'model_Venue'),
#  (0.0, 'model_V60 Cross Country'),
#  (0.0, 'model_V50'),
#  (0.0, 'model_UX'),
#  (0.0, 'model_Transit Connect'),
#  (0.0, 'model_Transit'),
#  (0.0, 'model_Town Car'),
#  (0.0, 'model_Tiguan Limited'),
#  (0.0, 'model_Thunderbird'),
#  (0.0, 'model_Telluride'),
#  (0.0, 'model_TT'),
#  (0.0, 'model_Stinger'),
#  (0.0, 'model_Stelvio'),
#  (0.0, 'model_Sprinter Passenger Van'),
#  (0.0, 'model_Sprinter Cargo Van'),
#  (0.0, 'model_Sonata Hybrid'),
#  (0.0, 'model_Solstice'),
#  (0.0, 'model_Silverado 3500 Chassis Cab'),
#  (0.0, 'model_Sierra'),
#  (0.0, 'model_Sequoia'),
#  (0.0, 'model_Seltos'),
#  (0.0, 'model_Santa Fe Sport'),
#  (0.0, 'model_SQ5'),
#  (0.0, 'model_SLK-Class'),
#  (0.0, 'model_S4'),
#  (0.0, 'model_Rio'),
#  (0.0, 'model_Ranger'),
#  (0.0, 'model_Range Rover Evoque'),
#  (0.0, 'model_Ram Pickup'),
#  (0.0, 'model_RX Hybrid'),
#  (0.0, 'model_RS 7'),
#  (0.0, 'model_RIO'),
#  (0.0, 'model_RC'),
#  (0.0, 'model_R-Class'),
#  (0.0, 'model_Quest'),
#  (0.0, 'model_Quattroporte'),
#  (0.0, 'model_QX70'),
#  (0.0, 'model_QX50'),
#  (0.0, 'model_QX30'),
#  (0.0, 'model_QX'),
#  (0.0, 'model_Q60 Coupe'),
#  (0.0, 'model_Q50'),
#  (0.0, 'model_Q5'),
#  (0.0, 'model_Q3'),
#  (0.0, 'model_ProMaster Cargo Van'),
#  (0.0, 'model_Prius Prime'),
#  (0.0, 'model_Pacifica Hybrid'),
#  (0.0, 'model_Outlander Sport'),
#  (0.0, 'model_Niro'),
#  (0.0, 'model_New Beetle'),
#  (0.0, 'model_Nautilus'),
#  (0.0, 'model_NV200'),
#  (0.0, 'model_Montego'),
#  (0.0, 'model_Mirage G4'),
#  (0.0, 'model_Mirage'),
#  (0.0, 'model_Mazda6'),
#  (0.0, 'model_Matrix'),
#  (0.0, 'model_Mariner'),
#  (0.0, 'model_MX-5 Miata'),
#  (0.0, 'model_M6 Convertible'),
#  (0.0, 'model_M4 Convertible'),
#  (0.0, 'model_M-Class'),
#  (0.0, 'model_Levante'),
#  (0.0, 'model_Lancer'),
#  (0.0, 'model_LX'),
#  (0.0, 'model_K900'),
#  (0.0, 'model_Juke'),
#  (0.0, 'model_JUKE'),
#  (0.0, 'model_Ioniq'),
#  (0.0, 'model_ILX'),
#  (0.0, 'model_Huracan'),
#  (0.0, 'model_Hardtop 4 Door'),
#  (0.0, 'model_H2'),
#  (0.0, 'model_Grand Marquis'),
#  (0.0, 'model_Grand Am'),
#  (0.0, 'model_Golf'),
#  (0.0, 'model_Ghibli'),
#  (0.0, 'model_Genesis Coupe'),
#  (0.0, 'model_Genesis'),
#  (0.0, 'model_GS'),
#  (0.0, 'model_GLA-Class'),
#  (0.0, 'model_GL-Class'),
#  (0.0, 'model_G90'),
#  (0.0, 'model_G Coupe'),
#  (0.0, 'model_G'),
#  (0.0, 'model_Forte Koup'),
#  (0.0, 'model_FR-S'),
#  (0.0, 'model_FJ Cruiser'),
#  (0.0, 'model_F-Pace'),
#  (0.0, 'model_F-PACE'),
#  (0.0, 'model_F-450 Super Duty Chassis Cab'),
#  (0.0, 'model_Express Cargo'),
#  (0.0, 'model_Explorer Sport Trac'),
#  (0.0, 'model_Elantra Touring'),
#  (0.0, 'model_Econoline Van'),
#  (0.0, 'model_E-Series Econoline Van'),
#  (0.0, 'model_E-Series Cutaway'),
#  (0.0, 'model_Discovery'),
#  (0.0, 'model_Corsair'),
#  (0.0, 'model_Corolla Hatchback'),
#  (0.0, 'model_Clarity'),
#  (0.0, 'model_Civic Hatchback'),
#  (0.0, 'model_Cadenza'),
#  (0.0, 'model_CX-30'),
#  (0.0, 'model_CTS-V Coupe'),
#  (0.0, 'model_CTS Sport Sedan'),
#  (0.0, 'model_CTS Sedan'),
#  (0.0, 'model_CTS Coupe'),
#  (0.0, 'model_CT6'),
#  (0.0, 'model_CLA'),
#  (0.0, 'model_C-Max'),
#  (0.0, 'model_C-Class Cabriolet'),
#  (0.0, 'model_Bronco Sport'),
#  (0.0, 'model_Blazer'),
#  (0.0, 'model_Beetle'),
#  (0.0, 'model_Baja'),
#  (0.0, 'model_BRZ'),
#  (0.0, 'model_Atlas Cross Sport'),
#  (0.0, 'model_Arteon'),
#  (0.0, 'model_Altima Hybrid'),
#  (0.0, 'model_All-New Wrangler'),
#  (0.0, 'model_Acadia Limited'),
#  (0.0, 'model_ATS-V Coupe'),
#  (0.0, 'model_ATS Sedan'),
#  ...]

# %% [markdown]
# # Luxury Makes
# After the model focusing on makes, the next step was to process the data even more so that the makes are split on luxury and non luxury makes. This is because the pricing and quality of luxury makes create a bias when comparing to regular makes.

# %%
clean_df = pd.read_csv('luxury_makes.csv')

# %%
clean_df = clean_df.drop(columns=['id', 'vin', 'body_type', 'vehicle_type', 'drivetrain', 'fuel_type', 'engine_size', 'engine_block'])

# %%
clean_df = clean_df.dropna()

# %%
clean_df['price'] = pd.cut(clean_df['price'], bins, labels=labels )

# %%
clean_df['make'].unique()
# Out:
# array(['BMW', 'Mercedes-Benz', 'Lexus', 'Porsche', 'Audi', 'Lamborghini',
#        'Alfa Romeo', 'Ferrari', 'Maserati', 'Jaguar', 'Aston Martin',
#        'Bentley', 'Land Rover', 'Cadillac', 'Rolls-Royce', 'INFINITI',
#        'Maybach', 'Acura', 'Fisker', 'McLaren', 'Lotus'], dtype=object)

# %%
luxury_make_df = clean_df.sample(n=5000)

# %%
X = pd.get_dummies(luxury_make_df)
X = X.drop(columns=["price_0-4,999", "price_5,000-9,999", "price_10,000-14999", "price_15,000-24,999", "price_25,000-49,999", "price_50,000-99,999", "price_100,000-400,000"])
y = luxury_make_df['price']

# %%
X
# Out:
#             miles    year  make_Acura  make_Alfa Romeo  make_Aston Martin  \
# 9932      32891.0  2019.0           0                0                  0
# 89993     39600.0  2018.0           0                0                  0
# 840273   124944.0  2007.0           0                0                  0
# 1050898   43719.0  2018.0           0                0                  0
# 891833    11469.0  2018.0           0                0                  0
# ...           ...     ...         ...              ...                ...
# 92174     22336.0  2017.0           0                0                  0
# 1057277   41561.0  2017.0           0                0                  0
# 422294    43851.0  2018.0           0                0                  0
# 114611    19075.0  2018.0           0                0                  0
# 141328    53960.0  2017.0           0                0                  0
#
#          make_Audi  make_BMW  make_Bentley  make_Cadillac  make_Ferrari  ...  \
# 9932             0         1             0              0             0  ...
# 89993            1         0             0              0             0  ...
# 840273           0         0             0              0             0  ...
# 1050898          0         0             0              0             0  ...
# 891833           0         0             0              0             0  ...
# ...            ...       ...           ...            ...           ...  ...
# 92174            1         0             0              0             0  ...
# 1057277          0         0             0              0             0  ...
# 422294           0         0             0              0             0  ...
# 114611           0         1             0              0             0  ...
# 141328           0         1             0              0             0  ...
#
#          trim_xDrive28i  trim_xDrive30i  trim_xDrive35d  trim_xDrive35i  \
# 9932                  0               0               0               0
# 89993                 0               0               0               0
# 840273                0               0               0               0
# 1050898               0               0               0               0
# 891833                0               0               0               0
# ...                 ...             ...             ...             ...
# 92174                 0               0               0               0
# 1057277               0               0               0               0
# 422294                0               0               0               0
# 114611                0               0               0               0
# 141328                0               0               0               0
#
#          trim_xDrive35i Premium  trim_xDrive40e  trim_xDrive48i  \
# 9932                          0               0               0
# 89993                         0               0               0
# 840273                        0               0               0
# 1050898                       0               0               0
# 891833                        0               0               0
# ...                         ...             ...             ...
# 92174                         0               0               0
# 1057277                       0               0               0
# 422294                        0               0               0
# 114611                        0               0               0
# 141328                        0               0               0
#
#          trim_xDrive50i  transmission_Automatic  transmission_Manual
# 9932                  0                       1                    0
# 89993                 0                       1                    0
# 840273                0                       1                    0
# 1050898               0                       1                    0
# 891833                0                       1                    0
# ...                 ...                     ...                  ...
# 92174                 0                       1                    0
# 1057277               0                       1                    0
# 422294                0                       1                    0
# 114611                0                       1                    0
# 141328                0                       1                    0
#
# [5000 rows x 559 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (3750, 559)

# %%
clf = BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22060\1518962397.py in <module>
# ----> 1 clf = BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_train, y_train)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\imblearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     443             raise ValueError("sparse multilabel-indicator for y is not supported.")
#     444         X, y = self._validate_data(
# --> 445             X, y, multi_output=True, accept_sparse="csc", dtype=DTYPE
#     446         )
#     447         if sample_weight is not None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     579                 y = check_array(y, **check_y_params)
#     580             else:
# --> 581                 X, y = check_X_y(X, y, **check_params)
#     582             out = X, y
#     583
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     977     )
#     978
# --> 979     y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     980
#     981     check_consistent_length(X, y)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in _check_y(y, multi_output, y_numeric)
#     988     if multi_output:
#     989         y = check_array(
# --> 990             y, accept_sparse="csr", force_all_finite=True, ensure_2d=False, dtype=None
#     991         )
#     992     else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     798
#     799         if force_all_finite:
# --> 800             _assert_all_finite(array, allow_nan=force_all_finite == "allow-nan")
#     801
#     802     if ensure_min_samples > 0:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sklearn\utils\validation.py in _assert_all_finite(X, allow_nan, msg_dtype)
#     120     elif X.dtype == np.dtype("object") and not allow_nan:
#     121         if _object_dtype_isnan(X).any():
# --> 122             raise ValueError("Input contains NaN")
#     123
#     124
#
# ValueError: Input contains NaN

# %%
# Display the confusion matrix
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)

# %%
balanced_accuracy_score(y_test, y_pred)

# %%
print(classification_report_imbalanced(y_test, y_pred))

# %%
# List the features sorted in descending order by feature importance
sorted(zip(clf.feature_importances_, X.columns), reverse=True)

# %% [markdown]
# # Non-Luxury Makes

# %%
clean_df = pd.read_csv('regular_makes.csv')

# %%
clean_df = clean_df.drop(columns=['id', 'vin', 'body_type', 'vehicle_type', 'drivetrain', 'fuel_type', 'engine_size', 'engine_block'])

# %%
clean_df = clean_df.dropna()

# %%
clean_df['make'].unique()
# Out:
# array(['Chevrolet', 'Mitsubishi', 'Dodge', 'RAM', 'Ford', 'Mercury',
#        'GMC', 'smart', 'Jeep', 'Pontiac', 'Volvo', 'Scion', 'Buick',
#        'Toyota', 'Lincoln', 'Honda', 'FIAT', 'Saturn', 'Oldsmobile',
#        'Kia', 'Chrysler', 'Saab', 'Volkswagen', 'Isuzu', 'Subaru',
#        'Am General', 'Hummer', 'Mazda', 'MINI', 'Hyundai', 'Nissan',
#        'Suzuki', 'GENESIS', 'KARMA', 'Plymouth', 'Geo', 'Eagle'],
#       dtype=object)

# %%
clean_df['price'] = pd.cut(clean_df['price'], bins, labels=labels )

# %%
regular_make_df = clean_df.sample(n=5000)

# %%
X = pd.get_dummies(regular_make_df)
X = X.drop(columns=["price_0-4,999", "price_5,000-9,999", "price_10,000-14999", "price_15,000-24,999", "price_25,000-49,999", "price_50,000-99,999", "price_100,000-400,000"])
y = regular_make_df['price']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, 
                                                    y, 
                                                    random_state=1)
X_train.shape
# Out:
# (3750, 716)

# %%
clf = BalancedRandomForestClassifier(random_state=1, n_estimators=100).fit(X_train, y_train)

# %%
# Display the confusion matrix
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[  5,   1,   1,   0,   0,   3,   0],
#        [ 12, 108,   2,   6,   9,  18,   3],
#        [  0,   0,   2,   0,   0,   0,   0],
#        [ 10, 113,  40, 111, 163,  12,  43],
#        [  1,  41,  79,  31, 190,   3,  73],
#        [ 43,  24,   1,   0,   0,  32,   1],
#        [  0,   4,  21,   3,  16,   0,  25]], dtype=int64)

# %%
balanced_accuracy_score(y_test, y_pred)
# Out:
# 0.5061214340269301

# %%
print(classification_report_imbalanced(y_test, y_pred))
# Out:
#                        pre       rec       spe        f1       geo       iba       sup
#
#         0-4,999       0.07      0.50      0.95      0.12      0.69      0.45        10
#    10,000-14999       0.37      0.68      0.83      0.48      0.75      0.56       158
# 100,000-400,000       0.01      1.00      0.88      0.03      0.94      0.89         2
#   15,000-24,999       0.74      0.23      0.95      0.35      0.46      0.20       492
#   25,000-49,999       0.50      0.45      0.77      0.48      0.59      0.34       418
#     5,000-9,999       0.47      0.32      0.97      0.38      0.55      0.29       101
#   50,000-99,999       0.17      0.36      0.90      0.23      0.57      0.31        69
#
#     avg / total       0.55      0.38      0.87      0.40      0.56      0.31      1250

# %%
# List the features sorted in descending order by feature importance
sorted(zip(clf.feature_importances_, X.columns), reverse=True)
# Out:
# [(0.12951188496544289, 'miles'),
#  (0.10980796489652513, 'year'),
#  (0.032971074537560895, 'make_Chevrolet'),
#  (0.026461198616886374, 'model_Corvette'),
#  (0.023662342412183332, 'make_Ford'),
#  (0.01843895961138068, 'make_Toyota'),
#  (0.017231509950165345, 'transmission_Automatic'),
#  (0.015411531279255626, 'model_Ram 1500 Pickup'),
#  (0.015297946997911769, 'model_F-150'),
#  (0.014702922053003172, 'trim_3ZR'),
#  (0.014480654578421175, 'trim_2LT'),
#  (0.01387947540826918, 'make_Honda'),
#  (0.013672090058439086, 'make_Dodge'),
#  (0.01255989877570844, 'transmission_Manual'),
#  (0.012174947494564553, 'trim_Base'),
#  (0.011796563953845748, 'make_RAM'),
#  (0.011485384961557554, 'make_GMC'),
#  (0.011170870794059285, 'make_Nissan'),
#  (0.010860555463286665, 'trim_SE'),
#  (0.01016186666613428, 'trim_S'),
#  (0.009633049233344255, 'trim_LX'),
#  (0.008899776640824832, 'make_Jeep'),
#  (0.00888603507280981, 'model_F-250 Super Duty'),
#  (0.008211014638543733, 'trim_XLT'),
#  (0.007854672943799032, 'model_Silverado 1500'),
#  (0.007749501843149739, 'trim_LT'),
#  (0.007581156152072411, 'trim_TRX'),
#  (0.007545626515688337, 'trim_Limited'),
#  (0.007328756462468003, 'model_Cruze'),
#  (0.007163657918716757, 'make_Hyundai'),
#  (0.006957459369731616, 'make_Subaru'),
#  (0.006928590370218926, 'trim_LS'),
#  (0.006912824918158641, 'model_Malibu'),
#  (0.006788988401283045, 'model_Compass'),
#  (0.006507110889353987, 'trim_Denali'),
#  (0.006091325427009444, 'trim_1LT'),
#  (0.00600838233786497, 'trim_XL'),
#  (0.005831485535469332, 'trim_LE'),
#  (0.005756542048825459, 'make_Kia'),
#  (0.005663320621656706, 'trim_Latitude'),
#  (0.005509193106815714, 'trim_EX-L'),
#  (0.005334114525761624, 'trim_SL'),
#  (0.005238644041229514, 'trim_LTZ'),
#  (0.005115557657481456, 'trim_SEL'),
#  (0.00493515909867524, 'model_Altima'),
#  (0.00484270631296903, 'model_Escape'),
#  (0.004574290424560364, 'make_Volkswagen'),
#  (0.0045425930251204415, 'make_Mazda'),
#  (0.0044691044322530925, 'model_Grand Cherokee'),
#  (0.004347542733918321, 'make_Lincoln'),
#  (0.00427423893612488, 'model_Murano'),
#  (0.004267159072042809, 'model_New Beetle'),
#  (0.004266618498768997, 'make_Chrysler'),
#  (0.0042507855480356125, 'model_Accord'),
#  (0.004228816784648509, 'model_Silverado 2500HD'),
#  (0.004180514681444371, 'trim_Lariat'),
#  (0.004095092988550712, 'model_Camry'),
#  (0.003971620798542213, 'trim_SV'),
#  (0.00396071379445812, 'model_Corolla'),
#  (0.0038540960225666924, 'model_Sierra 2500 Denali HD'),
#  (0.0038416805129073105, 'trim_Touring'),
#  (0.0037612218721586434, 'model_Sonata'),
#  (0.0037247156082784137, 'trim_Sport'),
#  (0.0035937917780748648, 'make_MINI'),
#  (0.0035779549115588904, 'trim_ES'),
#  (0.0035702260281862976, 'trim_i'),
#  (0.003457174430661942, 'model_Accent'),
#  (0.003418769936794541, 'trim_High Country'),
#  (0.003272553812769667, 'model_Rogue'),
#  (0.003240129350706274, 'model_Jetta'),
#  (0.003237744657414588, 'model_Sierra 1500'),
#  (0.003112021758169787, 'model_Suburban'),
#  (0.002964196094515778, 'trim_GLS'),
#  (0.002955346963188273, 'model_Sierra 1500 Denali'),
#  (0.0029223865877712023, 'trim_Big Horn/Lone Star'),
#  (0.002907103825136612, 'model_Sentra'),
#  (0.0028122591294591657, 'model_Explorer'),
#  (0.002806977909484305, 'model_Durango'),
#  (0.002801340898465723, 'model_Pilot'),
#  (0.0028009190868713125, 'trim_Rebel'),
#  (0.002767797038601537, 'model_Tahoe'),
#  (0.0026823268443305483, 'model_Sportage'),
#  (0.002673915789679806, 'model_Yukon'),
#  (0.0026669569418522176, 'model_Equinox'),
#  (0.002598070508360661, 'model_Tacoma'),
#  (0.0025546210335914347, 'model_S40'),
#  (0.0024666626184114636, 'make_Saturn'),
#  (0.0024499572201499903, 'model_Optima'),
#  (0.0024253565062388595, 'model_Silverado 3500HD'),
#  (0.002419592555057919, 'trim_SXT'),
#  (0.0023997751520576306, 'model_Sable'),
#  (0.0023942806143973008, 'model_Carnival'),
#  (0.002388775973961553, 'trim_i Sport'),
#  (0.002359228896340948, 'model_Grand Caravan'),
#  (0.0022605274598632963, 'trim_XLE'),
#  (0.0022031746031746027, 'trim_Hybrid'),
#  (0.0021671322160148982, 'model_Soul'),
#  (0.0020661239699391043, 'model_Camaro'),
#  (0.0020384772429131153, 'trim_EX'),
#  (0.002019647737625266, 'model_All-New Wrangler Unlimited'),
#  (0.002004856438927319, 'trim_GT'),
#  (0.0019789438885145015, 'trim_Titanium'),
#  (0.0019542063414155295, 'model_Fusion'),
#  (0.0019150071950583452, 'make_Suzuki'),
#  (0.0018900675024107996, 'trim_XR'),
#  (0.001857247868274039, 'model_Canyon'),
#  (0.0018508295194508012, 'model_Regal'),
#  (0.0018452677224736042, 'model_Ram 2500 Pickup'),
#  (0.0018318863168651368, 'trim_Trailhawk'),
#  (0.0018133854421104063, 'trim_SLE'),
#  (0.0017449884981925743, 'trim_Z71'),
#  (0.001740437158469945, 'model_Versa Sedan'),
#  (0.0016986373342459534, 'model_Impreza'),
#  (0.0016137708445400755, 'model_Sorento'),
#  (0.0015976323490289974, 'model_Odyssey'),
#  (0.001558869829551624, 'trim_3LT'),
#  (0.0015506484689577675, 'model_Impala'),
#  (0.0015473453177257523, 'model_Colorado'),
#  (0.001524275393115172, 'model_MKX'),
#  (0.0015220893970893966, 'trim_+'),
#  (0.0015105894094433964, 'model_Grand Prix'),
#  (0.001488509830550326, 'model_Edge'),
#  (0.0014538461538461539, 'trim_Latitude Plus'),
#  (0.0014444444444444435, 'trim_Preferred'),
#  (0.0014102564102564097, 'model_Fit'),
#  (0.0013190414125516415, 'trim_Sport SE'),
#  (0.0012923076923076918, 'model_Sierra 2500HD'),
#  (0.0012831623741515722, 'model_F-350 Super Duty'),
#  (0.0012827715355805253, 'model_Town Car'),
#  (0.0012807017543859645, 'model_Terrain'),
#  (0.0012382860054924844, 'model_ProMaster Cargo Van'),
#  (0.0012191011235955062, 'trim_i Touring'),
#  (0.0012138728323699422, 'model_Renegade'),
#  (0.0012054132657847837, 'model_Journey'),
#  (0.0011927374301675987, 'model_Pacifica'),
#  (0.0011731843575418994, 'model_Avalanche'),
#  (0.0011589403973509937, 'trim_2.0 S'),
#  (0.0011470037453183521, 'trim_SL1'),
#  (0.0011470029109487316, 'model_Dart'),
#  (0.0011370056497175148, 'model_Liberty'),
#  (0.001129032258064516, 'trim_Premium'),
#  (0.001129032258064516, 'model_200'),
#  (0.0011205821205821204, 'make_Mercury'),
#  (0.0010981507823613077, 'model_Focus'),
#  (0.0010939226519337015, 'make_Buick'),
#  (0.001075147762454264, 'trim_Power Wagon'),
#  (0.0010568148793955246, 'model_Tundra'),
#  (0.0010529465046888325, 'model_RAV4'),
#  (0.001044407400732865, 'model_Outlook'),
#  (0.0010403225806451613, 'trim_Laramie'),
#  (0.001030555555555555, 'trim_G6'),
#  (0.001022199893413866, 'model_CX-5'),
#  (0.0010209593777009503, 'model_Ridgeline'),
#  (0.0009822990981289551, 'make_Oldsmobile'),
#  (0.000957264957264956, 'model_C-HR'),
#  (0.0009280303030303025, 'model_WRX'),
#  (0.0009112426035502967, 'trim_SLT'),
#  (0.000905008165487207, 'make_Mitsubishi'),
#  (0.0009032258064516125, 'trim_SR'),
#  (0.0008978118655538006, 'make_Volvo'),
#  (0.0008977384039181796, 'trim_SR5'),
#  (0.0008798882681564246, 'make_FIAT'),
#  (0.0008705357142857142, 'model_Savana Cargo'),
#  (0.000855978260869565, 'model_Transit Van'),
#  (0.0008467741935483871, 'trim_Rubicon'),
#  (0.0008284023668639052, 'model_Rogue Sport'),
#  (0.0008076923076923079, 'make_Pontiac'),
#  (0.0007999999999999999, 'model_Enclave'),
#  (0.0007983056370153152, 'trim_Tradesman'),
#  (0.0007865168539325843, 'model_Golf'),
#  (0.0007734806629834255, 'trim_Reserve'),
#  (0.0007734806629834255, 'model_Kicks'),
#  (0.0007692307692307692, 'trim_SX'),
#  (0.0007688376901491653, 'trim_XE'),
#  (0.0007600000000000003, 'model_JUKE'),
#  (0.0007457386363636363, 'trim_TRD Off-Road Premium'),
#  (0.0007370071684587817, 'trim_GT2'),
#  (0.0007211538461538457, 'model_Santa Fe'),
#  (0.0007196969696969692, 'trim_Sport S'),
#  (0.0007189189189189194, 'model_Wrangler Unlimited'),
#  (0.0007140255009107459, 'trim_Sahara'),
#  (0.0007045880149812735, 'model_Golf SportWagen'),
#  (0.0006982456140350873, 'model_Rio'),
#  (0.0006932453021838498, 'trim_R'),
#  (0.0006923076923076922, 'model_Insight'),
#  (0.0006862745098039223, 'trim_2.4i'),
#  (0.0006847826086956521, 'trim_Willys Wheeler'),
#  (0.0006843575418994415, 'model_Prius Prime'),
#  (0.0006768341307814983, 'make_Scion'),
#  (0.0006754385964912275, 'model_Avenger'),
#  (0.000662162162162162, 'trim_AT4'),
#  (0.0006567796610169495, 'model_Expedition'),
#  (0.000652173913043478, 'model_Ram 1500 Classic'),
#  (0.0006435137895812058, 'trim_Summit'),
#  (0.0006304385659589274, 'model_Atlas'),
#  (0.0006277173913043475, 'model_Tiguan'),
#  (0.0006271186440677965, 'trim_Platinum'),
#  (0.0006249999999999999, 'model_Elantra'),
#  (0.000621301775147929, 'trim_High Altitude'),
#  (0.0006187845303867408, 'trim_FX4'),
#  (0.000607237276933245, 'trim_Pop'),
#  (0.0005932203389830508, 'trim_LXS'),
#  (0.0005833333333333334, 'model_Veloster'),
#  (0.0005833333333333333, 'model_Forte'),
#  (0.000580110497237569, 'model_Pathfinder'),
#  (0.00057476231633535, 'model_Navigator'),
#  (0.0005747368421052642, 'model_MAZDA6'),
#  (0.0005737704918032786, 'trim_Grand Touring AWD'),
#  (0.0005725806451612913, 'trim_V6'),
#  (0.0005711186568571979, 'trim_4.0'),
#  (0.0005706521739130434, 'trim_TRD Sport'),
#  (0.0005675675675675676, 'trim_Raptor'),
#  (0.0005675675675675676, 'model_Venza'),
#  (0.000564516129032258, 'trim_Si'),
#  (0.0005605214152700187, 'model_Cavalier'),
#  (0.0005563858695652171, 'model_Traverse'),
#  (0.0005530145530145531, 'trim_Laramie Longhorn'),
#  (0.000552074330164219, 'model_Crosstrek'),
#  (0.0005385670881113384, 'trim_Custom'),
#  (0.0005366093366093366, 'trim_TRD Pro'),
#  (0.0005142045454545458, 'model_Ranger'),
#  (0.0005016722408026749, 'model_Ram 3500 Pickup'),
#  (0.0004979281767955807, 'trim_RTS'),
#  (0.0004918032786885244, 'model_Genesis'),
#  (0.00048307591192901783, 'trim_Shelby GT350'),
#  (0.0004745762711864408, 'model_Avalon'),
#  (0.00046666666666666655, 'trim_V6 Premium'),
#  (0.0004096441947565545, 'model_Aveo5'),
#  (0.0003804347826086957, 'model_Wrangler'),
#  (0.0003551912568306007, 'model_Fiesta'),
#  (0.00027932960893854654, 'trim_PreRunner'),
#  (0.00022702702702702697, 'model_Forester'),
#  (0.00019021739130434774, 'model_CR-V'),
#  (9.61538461538462e-05, 'trim_Select'),
#  (0.0, 'trim_tS'),
#  (0.0, 'trim_s Touring'),
#  (0.0, 'trim_s Grand Touring'),
#  (0.0, 'trim_i SV'),
#  (0.0, 'trim_i Premium'),
#  (0.0, 'trim_i Limited'),
#  (0.0, 'trim_i Grand Touring'),
#  (0.0, 'trim_ZX4 SE'),
#  (0.0, 'trim_ZL1'),
#  (0.0, 'trim_Z71 LTZ'),
#  (0.0, 'trim_Z51'),
#  (0.0, 'trim_Z06'),
#  (0.0, 'trim_XT Touring'),
#  (0.0, 'trim_XT Premium'),
#  (0.0, 'trim_XSE'),
#  (0.0, 'trim_XLT Premium'),
#  (0.0, 'trim_XLS'),
#  (0.0, 'trim_XLE Touring Hybrid'),
#  (0.0, 'trim_XLE Premium'),
#  (0.0, 'trim_XLE Limited'),
#  (0.0, 'trim_XLE Hybrid'),
#  (0.0, 'trim_X'),
#  (0.0, 'trim_Work Van'),
#  (0.0, 'trim_Work Truck 1WT'),
#  (0.0, 'trim_Work Truck'),
#  (0.0, 'trim_Work'),
#  (0.0, 'trim_Wolfsburg Edition'),
#  (0.0, 'trim_Winter'),
#  (0.0, 'trim_Warlock'),
#  (0.0, 'trim_WRX Premium'),
#  (0.0, 'trim_WRX'),
#  (0.0, 'trim_Value Edition'),
#  (0.0, 'trim_Value'),
#  (0.0, 'trim_VP'),
#  (0.0, 'trim_V6 Sport'),
#  (0.0, 'trim_V6 LIMITED'),
#  (0.0, 'trim_Upland'),
#  (0.0, 'trim_Ultimate'),
#  (0.0, 'trim_Type-R'),
#  (0.0, 'trim_Two Eco'),
#  (0.0, 'trim_Two'),
#  (0.0, 'trim_Turbo4'),
#  (0.0, 'trim_Turbo Diesel'),
#  (0.0, 'trim_Tundra Grade'),
#  (0.0, 'trim_Trekking'),
#  (0.0, 'trim_Trail Premium'),
#  (0.0, 'trim_Touring-L Plus'),
#  (0.0, 'trim_Touring-L'),
#  (0.0, 'trim_Touring L Plus'),
#  (0.0, 'trim_Touring L'),
#  (0.0, 'trim_Touring Elite'),
#  (0.0, 'trim_Three Touring'),
#  (0.0, 'trim_Three'),
#  (0.0, 'trim_TSI S'),
#  (0.0, 'trim_TRD Off Road'),
#  (0.0, 'trim_TRD'),
#  (0.0, 'trim_TDI'),
#  (0.0, 'trim_T6'),
#  (0.0, 'trim_T5 Dynamic'),
#  (0.0, 'trim_T5'),
#  (0.0, 'trim_T/A'),
#  (0.0, 'trim_Sport X'),
#  (0.0, 'trim_Sport Touring'),
#  (0.0, 'trim_Sport Premium'),
#  (0.0, 'trim_Sport Limited'),
#  (0.0, 'trim_Sport 2.0T'),
#  (0.0, 'trim_Signature'),
#  (0.0, 'trim_Shelby GT500'),
#  (0.0, 'trim_Select AWD'),
#  (0.0, 'trim_Scat Pack'),
#  (0.0, 'trim_Sahara Altitude'),
#  (0.0, 'trim_SXT Plus'),
#  (0.0, 'trim_SXL'),
#  (0.0, 'trim_SVT Raptor'),
#  (0.0, 'trim_STX'),
#  (0.0, 'trim_ST'),
#  (0.0, 'trim_SS'),
#  (0.0, 'trim_SRT8'),
#  (0.0, 'trim_SRT-8'),
#  (0.0, 'trim_SRT'),
#  (0.0, 'trim_SR5 Premium'),
#  (0.0, 'trim_SP'),
#  (0.0, 'trim_SLT1'),
#  (0.0, 'trim_SLT-2'),
#  (0.0, 'trim_SLT-1'),
#  (0.0, 'trim_SLE2'),
#  (0.0, 'trim_SLE-2'),
#  (0.0, 'trim_SLE-1'),
#  (0.0, 'trim_SHO'),
#  (0.0, 'trim_SES'),
#  (0.0, 'trim_SEL w/Sunroof'),
#  (0.0, 'trim_SEL R-Line'),
#  (0.0, 'trim_SEL Premium R-Line'),
#  (0.0, 'trim_SEL Premium'),
#  (0.0, 'trim_SEL Plus'),
#  (0.0, 'trim_SE w/Tech'),
#  (0.0, 'trim_SE Sport'),
#  (0.0, 'trim_SE Plus'),
#  (0.0, 'trim_SE Nightshade'),
#  (0.0, 'trim_SE Luxury'),
#  (0.0, 'trim_S Plus'),
#  (0.0, 'trim_Reserve I'),
#  (0.0, 'trim_Rallye'),
#  (0.0, 'trim_RTL-E'),
#  (0.0, 'trim_RST'),
#  (0.0, 'trim_RS'),
#  (0.0, 'trim_R/T'),
#  (0.0, 'trim_R-Spec'),
#  (0.0, 'trim_R-Line'),
#  (0.0, 'trim_R-Design Platinum'),
#  (0.0, 'trim_R-Design'),
#  (0.0, 'trim_Premium I'),
#  (0.0, 'trim_Premium Hybrid'),
#  (0.0, 'trim_Premium 2'),
#  (0.0, 'trim_Premium 1'),
#  (0.0, 'trim_Premier'),
#  (0.0, 'trim_Preferred II'),
#  (0.0, 'trim_Power Wagon ST'),
#  (0.0, 'trim_Popular'),
#  (0.0, 'trim_Police Sedan'),
#  (0.0, 'trim_Police'),
#  (0.0, 'trim_Plus'),
#  (0.0, 'trim_Platinum Reserve'),
#  (0.0, 'trim_PRO-4X'),
#  (0.0, 'trim_Overland'),
#  (0.0, 'trim_Outback Sport'),
#  (0.0, 'trim_Onyx Edition'),
#  (0.0, 'trim_Off-Road Premium'),
#  (0.0, 'trim_Night'),
#  (0.0, 'trim_Momentum'),
#  (0.0, 'trim_Luxury 4WD'),
#  (0.0, 'trim_Lusso'),
#  (0.0, 'trim_Lone Star'),
#  (0.0, 'trim_Limited Ultimate'),
#  (0.0, 'trim_Limited Sterling Edition'),
#  (0.0, 'trim_Limited Premium'),
#  (0.0, 'trim_Limited Platinum'),
#  (0.0, 'trim_Limited Hybrid'),
#  (0.0, 'trim_Limited Edition'),
#  (0.0, 'trim_Leather'),
#  (0.0, 'trim_Launch Edition'),
#  (0.0, 'trim_Latitude Lux'),
#  (0.0, 'trim_Laredo E'),
#  (0.0, 'trim_Laredo'),
#  (0.0, 'trim_Laramie Limited'),
#  (0.0, 'trim_LX-P'),
#  (0.0, 'trim_LX Hybrid'),
#  (0.0, 'trim_LTZ Z71'),
#  (0.0, 'trim_LT Z71'),
#  (0.0, 'trim_LT Trail Boss'),
#  (0.0, 'trim_LS Sport'),
#  (0.0, 'trim_LIMITED'),
#  (0.0, 'trim_LE Plus'),
#  (0.0, 'trim_LE Platinum'),
#  (0.0, 'trim_LAREDO'),
#  (0.0, 'trim_L'),
#  (0.0, 'trim_King Ranch'),
#  (0.0, 'trim_John Cooper Works'),
#  (0.0, 'trim_Jetta'),
#  (0.0, 'trim_Inscription'),
#  (0.0, 'trim_III'),
#  (0.0, 'trim_II'),
#  (0.0, 'trim_I Premium'),
#  (0.0, 'trim_I Limited'),
#  (0.0, 'trim_Hybrid EX-L'),
#  (0.0, 'trim_High Altitude Edition'),
#  (0.0, 'trim_Heat'),
#  (0.0, 'trim_Harvest'),
#  (0.0, 'trim_HYBRID'),
#  (0.0, 'trim_Grand Touring Reserve'),
#  (0.0, 'trim_Grand Touring'),
#  (0.0, 'trim_Grand Sport'),
#  (0.0, 'trim_GTI'),
#  (0.0, 'trim_GT-Line'),
#  (0.0, 'trim_GT Premium'),
#  (0.0, 'trim_GT Plus'),
#  (0.0, 'trim_GT Deluxe'),
#  (0.0, 'trim_GT Bullitt'),
#  (0.0, 'trim_GS'),
#  (0.0, 'trim_GLI Autobahn'),
#  (0.0, 'trim_GLI 35th Anniversary Edition'),
#  (0.0, 'trim_Freedom Edition'),
#  (0.0, 'trim_Fleet'),
#  (0.0, 'trim_FX2'),
#  (0.0, 'trim_Express'),
#  (0.0, 'trim_Exclaim'),
#  (0.0, 'trim_Essence'),
#  (0.0, 'trim_Elite'),
#  (0.0, 'trim_Edge'),
#  (0.0, 'trim_Eddie Bauer'),
#  (0.0, 'trim_EcoBoost Premium'),
#  (0.0, 'trim_EcoBoost'),
#  (0.0, 'trim_Eco'),
#  (0.0, 'trim_EX-T'),
#  (0.0, 'trim_EX-L V6'),
#  (0.0, 'trim_EX-L V-6'),
#  (0.0, 'trim_EX Hybrid'),
#  (0.0, 'trim_Dynamic'),
#  (0.0, 'trim_Daytona'),
#  (0.0, 'trim_DE'),
#  (0.0, 'trim_Crossroad Plus'),
#  (0.0, 'trim_Crossroad'),
#  (0.0, 'trim_CrossRoad'),
#  (0.0, 'trim_Crew'),
#  (0.0, 'trim_Countryman S'),
#  (0.0, 'trim_Countryman'),
#  (0.0, 'trim_Convenience'),
#  (0.0, 'trim_Commercial'),
#  (0.0, 'trim_Club'),
#  (0.0, 'trim_Cloth'),
#  (0.0, 'trim_Citadel'),
#  (0.0, 'trim_Cartier'),
#  (0.0, 'trim_CXL-1'),
#  (0.0, 'trim_CXL Premium'),
#  (0.0, 'trim_CXL'),
#  (0.0, 'trim_CX'),
#  (0.0, 'trim_CE'),
#  (0.0, 'trim_C Platinum'),
#  (0.0, 'trim_C'),
#  (0.0, 'trim_Boss 302'),
#  (0.0, 'trim_Black Label'),
#  (0.0, 'trim_Black Edition'),
#  (0.0, 'trim_Big Horn'),
#  (0.0, 'trim_Base/Premiere'),
#  (0.0, 'trim_Avenir'),
#  (0.0, 'trim_Autobahn'),
#  (0.0, 'trim_American Value Package'),
#  (0.0, 'trim_Altitude Package'),
#  (0.0, 'trim_Altitude'),
#  (0.0, 'trim_Alltrack SE'),
#  (0.0, 'trim_All Terrain'),
#  (0.0, 'trim_Adventure'),
#  (0.0, 'trim_Advanced'),
#  (0.0, 'trim_Abarth'),
#  (0.0, 'trim_75th Anniversary'),
#  (0.0, 'trim_50th Anniversary Special Edition'),
#  (0.0, 'trim_5.0'),
#  (0.0, 'trim_4X2 V 6 LIMITED'),
#  (0.0, 'trim_4.6'),
#  (0.0, 'trim_3.8'),
#  (0.0, 'trim_3.6R Limited'),
#  (0.0, 'trim_3.2'),
#  (0.0, 'trim_3.0 EX'),
#  (0.0, 'trim_2SS'),
#  (0.0, 'trim_2LZ'),
#  (0.0, 'trim_2LS'),
#  (0.0, 'trim_2.5i Premium'),
#  (0.0, 'trim_2.5i Limited'),
#  (0.0, 'trim_2.5XT Limited'),
#  (0.0, 'trim_2.5GT'),
#  (0.0, 'trim_2.5'),
#  (0.0, 'trim_2.0I Sport Limited'),
#  (0.0, 'trim_2.0I Premium'),
#  (0.0, 'trim_2.0I Limited'),
#  (0.0, 'trim_1SS'),
#  (0.0, 'trim_1SD'),
#  (0.0, 'trim_1SA'),
#  (0.0, 'trim_1RS'),
#  (0.0, 'trim_1LZ'),
#  (0.0, 'trim_1LS'),
#  (0.0, 'trim_1FL'),
#  (0.0, 'trim_1794 Edition'),
#  (0.0, 'trim_1.8'),
#  (0.0, 'model_xD'),
#  (0.0, 'model_xB'),
#  (0.0, 'model_tC'),
#  (0.0, 'model_iQ'),
#  (0.0, 'model_Yukon XL'),
#  (0.0, 'model_Yaris iA'),
#  (0.0, 'model_Yaris'),
#  (0.0, 'model_Xterra'),
#  (0.0, 'model_XV Crosstrek'),
#  (0.0, 'model_XC90'),
#  (0.0, 'model_XC70'),
#  (0.0, 'model_XC60'),
#  (0.0, 'model_XC40'),
#  (0.0, 'model_Wrangler JK Unlimited'),
#  (0.0, 'model_Wrangler JK'),
#  (0.0, 'model_WRX STI'),
#  (0.0, 'model_Volt'),
#  (0.0, 'model_Vibe'),
#  (0.0, 'model_Versa Note'),
#  (0.0, 'model_Versa'),
#  (0.0, 'model_Verano'),
#  (0.0, 'model_Veracruz'),
#  (0.0, 'model_V90 Cross Country'),
#  (0.0, 'model_V60'),
#  (0.0, 'model_Tucson'),
#  (0.0, 'model_Trax'),
#  (0.0, 'model_Transit Wagon'),
#  (0.0, 'model_Transit Passenger Van'),
#  (0.0, 'model_Transit Connect'),
#  (0.0, 'model_Transit'),
#  (0.0, 'model_Trailblazer'),
#  (0.0, 'model_Town & Country'),
#  (0.0, 'model_Touareg'),
#  (0.0, 'model_Titan XD'),
#  (0.0, 'model_Titan'),
#  (0.0, 'model_Tiguan Limited'),
#  (0.0, 'model_Telluride'),
#  (0.0, 'model_Taurus'),
#  (0.0, 'model_Supra'),
#  (0.0, 'model_Stinger'),
#  (0.0, 'model_Spectra'),
#  (0.0, 'model_Spark'),
#  (0.0, 'model_Sonic'),
#  (0.0, 'model_Sonata Hybrid'),
#  (0.0, 'model_Silverado 3500 Chassis Cab'),
#  (0.0, 'model_Silverado 1500 LD'),
#  (0.0, 'model_Silverado'),
#  (0.0, 'model_Sierra 3500HD'),
#  (0.0, 'model_Sierra 3500 Denali HD'),
#  (0.0, 'model_Sierra 3500 Chassis Cab'),
#  (0.0, 'model_Sierra 3500'),
#  (0.0, 'model_Sierra 1500 Limited'),
#  (0.0, 'model_Sienna'),
#  (0.0, 'model_Sequoia'),
#  (0.0, 'model_Seltos'),
#  (0.0, 'model_Sedona'),
#  (0.0, 'model_Santa Fe Sport'),
#  (0.0, 'model_SX4 Sport'),
#  (0.0, 'model_SS'),
#  (0.0, 'model_S90'),
#  (0.0, 'model_S80'),
#  (0.0, 'model_S60'),
#  (0.0, 'model_S2000'),
#  (0.0, 'model_S-Series'),
#  (0.0, 'model_Rondo'),
#  (0.0, 'model_Rogue Select'),
#  (0.0, 'model_Rio 5-Door'),
#  (0.0, 'model_Regal Sportback'),
#  (0.0, 'model_Ram 3500 Chassis Cab'),
#  (0.0, 'model_RIO'),
#  (0.0, 'model_Quest'),
#  (0.0, 'model_Promaster City'),
#  (0.0, 'model_Prius v'),
#  (0.0, 'model_Prius c'),
#  (0.0, 'model_Prius'),
#  (0.0, 'model_Patriot'),
#  (0.0, 'model_Passat'),
#  (0.0, 'model_Palisade'),
#  (0.0, 'model_Outlander Sport'),
#  (0.0, 'model_Outlander'),
#  (0.0, 'model_Outback'),
#  (0.0, 'model_Nitro'),
#  (0.0, 'model_Niro'),
#  (0.0, 'model_New Optima'),
#  (0.0, 'model_Nautilus'),
#  (0.0, 'model_NV200'),
#  (0.0, 'model_NV Cargo'),
#  (0.0, 'model_Mustang'),
#  (0.0, 'model_Mountaineer'),
#  (0.0, 'model_Monte Carlo'),
#  (0.0, 'model_Mirage G4'),
#  (0.0, 'model_Mirage'),
#  (0.0, 'model_Milan'),
#  (0.0, 'model_Miata'),
#  (0.0, 'model_Mazda6'),
#  (0.0, 'model_Mazda3'),
#  (0.0, 'model_Mazda2'),
#  (0.0, 'model_Maxima'),
#  (0.0, 'model_Matrix'),
#  (0.0, 'model_Mariner'),
#  (0.0, 'model_Magnum'),
#  (0.0, 'model_MX-5 Miata RF'),
#  (0.0, 'model_MX-5 Miata'),
#  (0.0, 'model_MKZ'),
#  (0.0, 'model_MKT'),
#  (0.0, 'model_MKS'),
#  (0.0, 'model_MKC'),
#  (0.0, 'model_MAZDA5'),
#  (0.0, 'model_MAZDA3'),
#  (0.0, 'model_Lucerne'),
#  (0.0, 'model_Legacy'),
#  (0.0, 'model_Land Cruiser'),
#  (0.0, 'model_Lancer'),
#  (0.0, 'model_LaCrosse'),
#  (0.0, 'model_Kona'),
#  (0.0, 'model_Jetta SportWagen'),
#  (0.0, 'model_Ioniq'),
#  (0.0, 'model_IONIQ'),
#  (0.0, 'model_Highlander'),
#  (0.0, 'model_Hardtop 4 Door'),
#  (0.0, 'model_HR-V'),
#  (0.0, 'model_HHR'),
#  (0.0, 'model_H2'),
#  (0.0, 'model_Grand Marquis'),
#  (0.0, 'model_Golf R'),
#  (0.0, 'model_Golf GTI'),
#  (0.0, 'model_Golf Alltrack'),
#  (0.0, 'model_Gladiator'),
#  (0.0, 'model_Genesis Coupe'),
#  (0.0, 'model_GTO'),
#  (0.0, 'model_GTI'),
#  (0.0, 'model_G90'),
#  (0.0, 'model_G80'),
#  (0.0, 'model_G8'),
#  (0.0, 'model_G70'),
#  (0.0, 'model_G6'),
#  (0.0, 'model_Fusion Hybrid'),
#  (0.0, 'model_Fusion Energi'),
#  (0.0, 'model_Frontier'),
#  (0.0, 'model_Freestyle'),
#  (0.0, 'model_Flex'),
#  (0.0, 'model_FR-S'),
#  (0.0, 'model_FORTE'),
#  (0.0, 'model_FJ Cruiser'),
#  (0.0, 'model_F-450 Super Duty Chassis Cab'),
#  (0.0, 'model_F-450 Super Duty'),
#  (0.0, 'model_F-350 Super Duty Chassis Cab'),
#  (0.0, 'model_Express Passenger'),
#  (0.0, 'model_Express Cargo'),
#  (0.0, 'model_Explorer Sport Trac'),
#  (0.0, 'model_Excursion'),
#  (0.0, 'model_Equus'),
#  (0.0, 'model_Envision'),
#  (0.0, 'model_Encore'),
#  (0.0, 'model_Elantra GT'),
#  (0.0, 'model_Ecosport'),
#  (0.0, 'model_Eclipse Cross'),
#  (0.0, 'model_E-Series Econoline Van'),
#  (0.0, 'model_Dakota'),
#  (0.0, 'model_Cruze Limited'),
#  (0.0, 'model_Crown Victoria'),
#  (0.0, 'model_Crosstour'),
#  (0.0, 'model_Countryman'),
#  (0.0, 'model_Corolla iM'),
#  (0.0, 'model_Corolla Hatchback'),
#  (0.0, 'model_Cooper'),
#  (0.0, 'model_Convertible'),
#  (0.0, 'model_Continental'),
#  (0.0, 'model_Cobalt'),
#  (0.0, 'model_Clubman'),
#  (0.0, 'model_Club Wagon'),
#  (0.0, 'model_Classic'),
#  (0.0, 'model_Clarity'),
#  (0.0, 'model_Civic Hatchback'),
#  (0.0, 'model_Civic'),
#  (0.0, 'model_Cherokee'),
#  (0.0, 'model_Charger'),
#  (0.0, 'model_Challenger'),
#  (0.0, 'model_Cascada'),
#  (0.0, 'model_Captiva Sport'),
#  (0.0, 'model_Camry Solara'),
#  (0.0, 'model_Caliber'),
#  (0.0, 'model_Cadenza'),
#  (0.0, 'model_CX-9'),
#  (0.0, 'model_CX-7'),
#  (0.0, 'model_CX-30'),
#  (0.0, 'model_CX-3'),
#  (0.0, 'model_CR-Z'),
#  (0.0, 'model_CC'),
#  (0.0, 'model_C-Max'),
#  (0.0, 'model_Blazer'),
#  (0.0, 'model_Beetle'),
#  (0.0, 'model_BRZ'),
#  (0.0, 'model_B9 Tribeca'),
#  (0.0, 'model_B-Series'),
#  (0.0, 'model_Aviator'),
#  (0.0, 'model_Aurora'),
#  (0.0, 'model_Aura'),
#  (0.0, 'model_Atlas Cross Sport'),
#  (0.0, 'model_Ascent'),
#  (0.0, 'model_Armada'),
#  (0.0, 'model_Altima Sedan'),
#  (0.0, 'model_Altima Coupe'),
#  (0.0, 'model_All-New Compass'),
#  (0.0, 'model_Accord Crosstour'),
#  (0.0, 'model_Acadia Limited'),
#  (0.0, 'model_Acadia'),
#  (0.0, 'model_9-3'),
#  (0.0, 'model_86'),
#  (0.0, 'model_500X'),
#  (0.0, 'model_500L'),
#  (0.0, 'model_500'),
#  (0.0, 'model_4Runner'),
#  (0.0, 'model_370Z Coupe'),
#  (0.0, 'model_300'),
#  (0.0, 'model_124 Spider'),
#  (0.0, 'make_Saab'),
#  (0.0, 'make_Hummer'),
#  (0.0, 'make_GENESIS')]

# %%
db_string = f"postgresql://postgres:{password}@localhost:5432/final_project_db"

# %%
engine=create_engine(db_string)
clean_df.to_sql(name='used_car_sample', con=engine)
make_df.to_sql(name='make_sample', con=engine)
# luxury_make_df.to_sql(name='luxury_sample', con=engine)
regular_make_df.to_sql(name='regular_sample', con=engine)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     206         try:
# --> 207             raise exception
#     208         finally:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#
# OperationalError: connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_22060\3812539098.py in <module>
#       1 engine=create_engine(db_string)
# ----> 2 clean_df.to_sql(name='used_car_sample', con=engine)
#       3 make_df.to_sql(name='make_sample', con=engine)
#       4 # luxury_make_df.to_sql(name='luxury_sample', con=engine)
#       5 regular_make_df.to_sql(name='regular_sample', con=engine)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2880             chunksize=chunksize,
#    2881             dtype=dtype,
# -> 2882             method=method,
#    2883         )
#    2884
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     726         method=method,
#     727         engine=engine,
# --> 728         **engine_kwargs,
#     729     )
#     730
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1756             index_label=index_label,
#    1757             schema=schema,
# -> 1758             dtype=dtype,
#    1759         )
#    1760
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1648             dtype=dtype,
#    1649         )
# -> 1650         table.create()
#    1651         return table
#    1652
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in create(self)
#     854
#     855     def create(self):
# --> 856         if self.exists():
#     857             if self.if_exists == "fail":
#     858                 raise ValueError(f"Table '{self.name}' already exists.")
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in exists(self)
#     838
#     839     def exists(self):
# --> 840         return self.pd_sql.has_table(self.name, self.schema)
#     841
#     842     def sql_schema(self):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\pandas\io\sql.py in has_table(self, name, schema)
#    1781             import sqlalchemy as sa
#    1782
# -> 1783             insp = sa.inspect(self.connectable)
#    1784             return insp.has_table(name, schema or self.meta.schema)
#    1785         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\inspection.py in inspect(subject, raiseerr)
#      62             if reg is True:
#      63                 return subject
# ---> 64             ret = reg(subject)
#      65             if ret is not None:
#      66                 break
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _engine_insp(bind)
#     180     @inspection._inspects(Engine)
#     181     def _engine_insp(bind):
# --> 182         return Inspector._construct(Inspector._init_engine, bind)
#     183
#     184     @inspection._inspects(Connection)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _construct(cls, init, bind)
#     115
#     116         self = cls.__new__(cls)
# --> 117         init(self, bind)
#     118         return self
#     119
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\reflection.py in _init_engine(self, engine)
#     126     def _init_engine(self, engine):
#     127         self.bind = self.engine = engine
# --> 128         engine.connect().close()
#     129         self._op_context_requires_connect = True
#     130         self.dialect = self.engine.dialect
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3208         """
#    3209
# -> 3210         return self._connection_cls(self, close_with_result=close_with_result)
#    3211
#    3212     @util.deprecated(
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3287
#    3288         """
# -> 3289         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3290
#    3291
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3258             if connection is None:
#    3259                 Connection._handle_dbapi_exception_noconnection(
# -> 3260                     e, dialect, self
#    3261                 )
#    3262             else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2105         elif should_wrap:
#    2106             util.raise_(
# -> 2107                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2108             )
#    2109         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3254         dialect = self.dialect
#    3255         try:
# -> 3256             return fn()
#    3257         except dialect.dbapi.Error as e:
#    3258             if connection is None:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     308
#     309         """
# --> 310         return _ConnectionFairy._checkout(self)
#     311
#     312     def _return_conn(self, record):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     866     def _checkout(cls, pool, threadconns=None, fairy=None):
#     867         if not fairy:
# --> 868             fairy = _ConnectionRecord.checkout(pool)
#     869
#     870             fairy._pool = pool
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     474     @classmethod
#     475     def checkout(cls, pool):
# --> 476         rec = pool._do_get()
#     477         try:
#     478             dbapi_connection = rec.get_connection()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144             except:
#     145                 with util.safe_reraise():
# --> 146                     self._dec_overflow()
#     147         else:
#     148             return self._do_get()
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141         if self._inc_overflow():
#     142             try:
# --> 143                 return self._create_connection()
#     144             except:
#     145                 with util.safe_reraise():
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     254         """Called by subclasses to create a new ConnectionRecord."""
#     255
# --> 256         return _ConnectionRecord(self)
#     257
#     258     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     369         self.__pool = pool
#     370         if connect:
# --> 371             self.__connect()
#     372         self.finalize_callback = deque()
#     373
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     664         except Exception as e:
#     665             with util.safe_reraise():
# --> 666                 pool.logger.debug("Error on connect(): %s", e)
#     667         else:
#     668             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      70                 compat.raise_(
#      71                     exc_value,
# ---> 72                     with_traceback=exc_tb,
#      73                 )
#      74         else:
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     659         try:
#     660             self.starttime = time.time()
# --> 661             self.dbapi_connection = connection = pool._invoke_creator(self)
#     662             pool.logger.debug("Created new connection %r", connection)
#     663             self.fresh = True
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     588                     if connection is not None:
#     589                         return connection
# --> 590             return dialect.connect(*cargs, **cparams)
#     591
#     592         creator = pop_kwarg("creator", connect)
#
# ~\anaconda3\envs\mlenv\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     595     def connect(self, *cargs, **cparams):
#     596         # inherits the docstring from interfaces.Dialect.connect
# --> 597         return self.dbapi.connect(*cargs, **cparams)
#     598
#     599     def create_connect_args(self, url):
#
# ~\anaconda3\envs\mlenv\lib\site-packages\psycopg2\__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     120
#     121     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 122     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     123     if cursor_factory is not None:
#     124         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) connection to server at "localhost" (::1), port 5432 failed: FATAL:  password authentication failed for user "postgres"
#
# (Background on this error at: https://sqlalche.me/e/14/e3q8)
