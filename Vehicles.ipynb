# %%
# Import Dependencies
import pandas as pd

# %%
# Read in file
file_path = "us-dealers-used.csv"
vehicles_df = pd.read_csv(file_path)
# Out:
# C:\Users\tvhs1\anaconda3\envs\mlenv\lib\site-packages\IPython\core\interactiveshell.py:3457: DtypeWarning: Columns (20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Show dataframe
vehicles_df
# Out:
#                     id                vin    price     miles    stock_no  \
# 0        38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0  W1T503168C
# 1        97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0      P33243
# 2        be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0     WM2091A
# 3        84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0    9U2Y425A
# 4        cde691c3-91dd  1G2AL18F087312093      NaN  188485.0     T36625A
# ...                ...                ...      ...       ...         ...
# 7104299  d02aa41a-4033  1FT7W2BT4KEF92394  69900.0   15270.0      AJ2815
# 7104300  987f3ec1-077a  1FT7W2BT0BEB86340  32991.0  143026.0    G581210A
# 7104301  f117918b-ab31  1FT7W2BT8MEC02433  82900.0    3686.0     210213A
# 7104302  86c89eea-b050  1FT7W2BT2KED70999  59995.0   39111.0       P6336
# 7104303  73b8c7c4-d061  1FT7W2BT8KEG61524  74985.0   18486.0     8U61524
#
#            year        make             model        trim  body_type  ...  \
# ...

# %%
# Drop NAs
dropped_df = vehicles_df.dropna()

# %%
# Show dropped dataframe
dropped_df
# Out:
#                     id                vin    price     miles    stock_no  \
# 0        38b2f52e-8f5d  1GCWGFCF3F1284719  20998.0  115879.0  W1T503168C
# 1        97ba4955-ccf0  WBY7Z8C59JVB87514  27921.0    7339.0      P33243
# 2        be1da9fd-0f34  ML32F4FJ2JHF10325  11055.0   39798.0     WM2091A
# 3        84327e45-6cb6  1GCPTEE15K1291189  52997.0   28568.0    9U2Y425A
# 6        43847b9a-6fed  1B7HC16Y8YS543285   3995.0  137537.0     BP8246A
# ...                ...                ...      ...       ...         ...
# 7104299  d02aa41a-4033  1FT7W2BT4KEF92394  69900.0   15270.0      AJ2815
# 7104300  987f3ec1-077a  1FT7W2BT0BEB86340  32991.0  143026.0    G581210A
# 7104301  f117918b-ab31  1FT7W2BT8MEC02433  82900.0    3686.0     210213A
# 7104302  86c89eea-b050  1FT7W2BT2KED70999  59995.0   39111.0       P6336
# 7104303  73b8c7c4-d061  1FT7W2BT8KEG61524  74985.0   18486.0     8U61524
#
#            year        make             model        trim  body_type  ...  \
# ...

# %%
# Show columns
dropped_df.columns
# Out:
# Index(['id', 'vin', 'price', 'miles', 'stock_no', 'year', 'make', 'model',
#        'trim', 'body_type', 'vehicle_type', 'drivetrain', 'transmission',
#        'fuel_type', 'engine_size', 'engine_block', 'seller_name', 'street',
#        'city', 'state', 'zip'],
#       dtype='object')

# %%
# Create new csv
dropped_df.to_csv("Used_Cars.csv")
